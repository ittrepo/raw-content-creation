# %% [markdown]
# ## Read json file from local.

# %%
import json

read_json_file = r"D:\content_for_hotel_json\cdn_row_collection\iryx\533451.json"

with open(read_json_file, 'r', encoding='utf-8') as file:
    data = json.load(file)

print(data)
# Out:
# {'hotel': {'id': 533451, 'name': 'AFFORDABLE BASSURA CITY APARTMENT', 'address': 'Jl. Basuki Rahmat No.1A Cipinang Besar Selatan, Jatinegara RT.8/RW.10 Cipinang Besar Selatan', 'telephone': None, 'fax': None, 'email': None, 'zipCode': None, 'stars': 3, 'recommended': False, 'specialDeal': False, 'country': {'id': 88, 'name': 'Indonesia', 'iso': 'ID'}, 'city': {'id': 24433, 'name': 'JAKARTA', 'countryId': 88}, 'geolocation': {'latitude': -6.223144, 'longitude': 106.878375}, '_links': {'self': {'href': 'https://satgurudmc.com/reseller/api/mapping/v1/hotels/533451/details'}, 'type': {'href': 'https://satgurudmc.com/reseller/api/mapping/v1/hotels/types/2128528824'}}}, 'type': {'id': 2128528824, 'language': 'EN', 'name': 'Hotels', 'priority': 0, 'addedOn': '2023-02-24 15:13:59', '_links': {'self': {'href': 'https://satgurudmc.com/reseller/api/mapping/v1/hotels/types/2128528824'}}}, 'images': {'_total_items': 6, '_page': 1, '_page_count': 1, '_links': {'self': {'href': 'https://satgurudmc.
# ...

# %%
formated_json_view = json.dumps(data, indent=4, ensure_ascii=False)
print(formated_json_view)
# Out:
# {
#     "hotel": {
#         "id": 533451,
#         "name": "AFFORDABLE BASSURA CITY APARTMENT",
#         "address": "Jl. Basuki Rahmat No.1A Cipinang Besar Selatan, Jatinegara RT.8/RW.10 Cipinang Besar Selatan",
#         "telephone": null,
#         "fax": null,
#         "email": null,
#         "zipCode": null,
#         "stars": 3,
#         "recommended": false,
#         "specialDeal": false,
#         "country": {
#             "id": 88,
#             "name": "Indonesia",
#             "iso": "ID"
#         },
#         "city": {
#             "id": 24433,
#             "name": "JAKARTA",
#             "countryId": 88
#         },
#         "geolocation": {
#             "latitude": -6.223144,
#             "longitude": 106.878375
#         },
#         "_links": {
#             "self": {
#                 "href": "https://satgurudmc.com/reseller/api/mapping/v1/hotels/533451/details"
#             },
#             "type": {
# ...

# %%
hotel_id = data.get("hotel").get("id")
hotel_name = data.get("hotel").get("name")
hotel_address = data.get("hotel").get("address")
hotel_telephone = data.get("hotel").get("telephone")
hotel_fax = data.get("hotel").get("fax")
hotel_email = data.get("hotel").get("email")
hotel_zipCode = data.get("hotel").get("zipCode")
hotel_stars = data.get("hotel").get("stars")
hotel_country_name = data.get("hotel").get("country").get("name")
hotel_country_iso = data.get("hotel").get("country").get("iso")
hotel_country_city = data.get("hotel").get("city").get("name")
hotel_geolocation = data.get("hotel").get("geolocation").get("latitude")
hotel_geolocation = data.get("hotel").get("geolocation").get("longitude")
hotel_type = data.get("type").get("name")


hotel_images = data.get("images").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")
hotel_id = data.get("hotel").get("address")

print(hotel_id)
# Out:
# 533451

# %%
formated_json_view = json.dumps(data, indent=4, ensure_ascii=False)
print(formated_json_view)
# Out:
# {
#     "hotel": {
#         "id": 533451,
#         "name": "AFFORDABLE BASSURA CITY APARTMENT",
#         "address": "Jl. Basuki Rahmat No.1A Cipinang Besar Selatan, Jatinegara RT.8/RW.10 Cipinang Besar Selatan",
#         "telephone": null,
#         "fax": null,
#         "email": null,
#         "zipCode": null,
#         "stars": 3,
#         "recommended": false,
#         "specialDeal": false,
#         "country": {
#             "id": 88,
#             "name": "Indonesia",
#             "iso": "ID"
#         },
#         "city": {
#             "id": 24433,
#             "name": "JAKARTA",
#             "countryId": 88
#         },
#         "geolocation": {
#             "latitude": -6.223144,
#             "longitude": 106.878375
#         },
#         "_links": {
#             "self": {
#                 "href": "https://satgurudmc.com/reseller/api/mapping/v1/hotels/533451/details"
#             },
#             "type": {
# ...

# %%
import json

read_json_file = r"D:\content_for_hotel_json\cdn_row_collection\iryx\533451.json"

with open(read_json_file, 'r', encoding='utf-8') as file:
    data = json.load(file)

hotel = data.get("hotel", {})
country = hotel.get("country", {})
city = hotel.get("city", {})
geolocation = hotel.get("geolocation", {})
hotel_type = data.get("type", {})
images_data = data.get("images", {})

# Handle images
gallery = images_data.get("_embedded", {}).get("gallery", [])
images = []
for item in gallery:
    images.append({
        "picture_id": item.get("id", None),
        "title": item.get("name", None),
        "url": item.get("url", None)
    })

primary_photo_url = images[0]["url"] if images else None

# Final structured data
formatted_data = {
    "hotel_id": hotel.get("id", None),
    "name": hotel.get("name", None),
    "name_local": None,
    "hotel_formerly_name": None,
    "destination_code": city.get("id", None),
    "country_code": country.get("iso", None),
    "brand_text": None,
    "property_type": hotel_type.get("name", None),
    "star_rating": hotel.get("stars", None),
    "chain": None,
    "brand": None,
    "logo": None,
    "primary_photo": primary_photo_url,
    "review_rating": {
        "source": None,
        "number_of_reviews": None,
        "rating_average": None,
        "popularity_score": None
    },
    "policies": {
        "check_in": {
            "begin_time": None,
            "end_time": None,
            "instructions": None,
            "min_age": None
        },
        "checkout": {
            "time": None
        },
        "fees": {
            "optional": None
        },
        "know_before_you_go": None,
        "pets": [],
        "remark": None,
        "child_and_extra_bed_policy": {
            "infant_age": None,
            "children_age_from": None,
            "children_age_to": None,
            "children_stay_free": None,
            "min_guest_age": None
        },
        "nationality_restrictions": None
    },
    "address": {
        "latitude": geolocation.get("latitude", None),
        "longitude": geolocation.get("longitude", None),
        "address_line_1": hotel.get("address", None),
        "address_line_2": None,
        "city": city.get("name", None),
        "state": None,
        "country": country.get("name", None),
        "country_code": country.get("iso", None),
        "postal_code": hotel.get("zipCode", None),
        "full_address": hotel.get("address", None),
        "google_map_site_link": None,
        "local_lang": {
            "latitude": None,
            "longitude": None,
            "address_line_1": None,
            "address_line_2": None,
            "city": None,
            "state": None,
            "country": None,
            "country_code": None,
            "postal_code": None,
            "full_address": None,
            "google_map_site_link": None
        },
        "mapping": {
            "continent_id": None,
            "country_id": country.get("id", None),
            "province_id": None,
            "state_id": None,
            "city_id": city.get("id", None),
            "area_id": None
        }
    },
    "contacts": {
        "phone_numbers": [hotel.get("telephone")] if hotel.get("telephone") else [],
        "fax": [hotel.get("fax")] if hotel.get("fax") else [],
        "email_address": [hotel.get("email")] if hotel.get("email") else [],
        "website": []
    },
    "descriptions": [
        {
            "title": None,
            "text": None
        }
    ],
    "room_type": [
        {
            "room_id": None,
            "title": None,
            "title_lang": None,
            "room_pic": None,
            "description": None,
            "max_allowed": {
                "total": None,
                "adults": None,
                "children": None,
                "infant": None
            },
            "no_of_room": None,
            "room_size": None,
            "bed_type": [
                {
                    "description": None,
                    "configuration": [],
                    "max_extrabeds": None
                }
            ],
            "shared_bathroom": None
        }
    ],
    "spoken_languages": [
        {
            "type": "spoken_languages",
            "title": None,
            "icon": "mdi mdi-translate-variant"
        }
    ],
    "amenities": [
        {
            "type": None,
            "title": None,
            "icon": "mdi mdi-translate-variant"
        }
    ],
    "facilities": [
        {
            "type": None,
            "title": None,
            "icon": "mdi mdi-translate-variant"
        }
    ],
    "hotel_photo": images
}

# Print JSON output
print(json.dumps(formatted_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "hotel_id": 533451,
#     "name": "AFFORDABLE BASSURA CITY APARTMENT",
#     "name_local": null,
#     "hotel_formerly_name": null,
#     "destination_code": 24433,
#     "country_code": "ID",
#     "brand_text": null,
#     "property_type": "Hotels",
#     "star_rating": 3,
#     "chain": null,
#     "brand": null,
#     "logo": null,
#     "primary_photo": "https://satgurudmc.com/reseller/assets/thumbnail?src=hotel:0/1/3/533451/751c99442c22f901e5ede84f4153e3f6cb84fc27.jpg",
#     "review_rating": {
#         "source": null,
#         "number_of_reviews": null,
#         "rating_average": null,
#         "popularity_score": null
#     },
#     "policies": {
#         "check_in": {
#             "begin_time": null,
#             "end_time": null,
#             "instructions": null,
#             "min_age": null
#         },
#         "checkout": {
#             "time": null
#         },
#         "fees": {
#             "optional": null
#         },
# ...
