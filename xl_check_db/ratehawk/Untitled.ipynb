# %% [markdown]
# ## Read main xlsx file.

# %%
import pandas as pd

df = pd.read_excel('Umrahbooking.xlsx')

print(df.head())
# Out:
#                                 Ratehawk Code  \
# 0  makkah_clock_royal_tower__a_fairmont_hotel
# 1                            swissotel_makkah
# 2                      rosh_rayhaan_by_rotana
# 3           anwar_al_madinah_moevenpick_hotel
# 4                      pullman_zamzam_madina_
#
#                           Hotel name                             Address  \
# 0  Fairmont Makkah Clock Royal Tower   King Abdul Aziz Endownment, Mecca
# 1                   Swissôtel Makkah    King Abdul Aziz Endowment, Mecca
# 2             Rosh Rayhaan by Rotana             Al Olaya Street, Riyadh
# 3   Anwar Al Madinah Mövenpick Hotel  Central Zone, Al Khalidiya, Medina
# 4              Pullman Zamzam Madina      Amr Bin Al Gmoh Street, Medina
#
#   Country Iso Hotel country Hotel city  Star rating   latitude  longitude  \
# 0          SA  Saudi Arabia      Mecca            5  21.418213  39.825176
# 1          SA  Saudi Arabia      Mecca            5  21.418900  39.827100
# 2          SA  Saudi Arabia     Riyadh            5  24.700377  46.682190
# 3          SA  Saudi Arabia     Medina            5  24.471216  39.607906
# 4          SA  Saudi Arabia     Medina            5  24.464329  39.611237
#
#   Mapped
# 0    yes
# 1    yes
# 2    yes
# 3    yes
# 4    yes

# %% [markdown]
# ### Only give headers

# %%
import pandas as pd

df = pd.read_excel('Umrahbooking.xlsx', nrows=0)

print(df.columns.tolist())
# Out:
# ['Ratehawk Code', 'Hotel name', 'Address', 'Country Iso', 'Hotel country', 'Hotel city', 'Star rating', 'latitude', 'longitude', 'Mapped', 'giata_present']

# %% [markdown]
# ### Add columns in xlsx file

# %%
# Get existing column names and add 'giata_present'
columns = df.columns.tolist() + ['giata_present']

print(columns)
# Out:
# ['Ratehawk Code', 'Hotel name', 'Address', 'Country Iso', 'Hotel country', 'Hotel city', 'Star rating', 'latitude', 'longitude', 'Mapped', 'giata_present', 'giata_present']

# %%
import pandas as pd

df = pd.read_excel('Umrahbooking.xlsx', nrows=0)

print(df.columns.tolist())
# Out:
# ['Ratehawk Code', 'Hotel name', 'Address', 'Country Iso', 'Hotel country', 'Hotel city', 'Star rating', 'latitude', 'longitude', 'Mapped', 'giata_present']

# %% [markdown]
# ### Add columns permanetly

# %%
import pandas as pd

df = pd.read_excel('Umrahbooking.xlsx')

df['giata_present'] = None  

df.to_excel('Umrahbooking.xlsx', index=False)

print("Column 'giata_present' added successfully!")
# Out:
# Column 'ratehawk_present' added successfully!

# %% [markdown]
# ### Get first row first column.

# %%
import pandas as pd

# Read the first row and first column only
df = pd.read_excel('Umrahbooking.xlsx', usecols=[0], nrows=1)

# Extract the value
first_value = df.iloc[0, 0]

print("First row, first column value:", first_value)
# Out:
# First row, first column value: makkah_clock_royal_tower__a_fairmont_hotel

# %% [markdown]
# ### Check and change status for giata id present or not

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
import time
from dotenv import load_dotenv
import os

load_dotenv()


GIATA_KEY = os.getenv("GIATA_API_key")

# Read the Excel file
df = pd.read_excel('Umrahbooking.xlsx')

# Ensure 'giata_present' column is of type string
df['giata_present'] = df['giata_present'].astype(str)

headers = {
    'Authorization': f'Basic {GIATA_KEY}'
}


# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    ratehawk_code = row['Ratehawk Code']
    url = f"https://multicodes.giatamedia.com/webservice/rest/1.0/properties/gds/ratehawk2/{ratehawk_code}"
    
    try:
        # Send POST request
        response = requests.post(url, headers=headers)
        response.raise_for_status()  # Raise exception for HTTP errors
        
        # Parse XML response
        root = ET.fromstring(response.content)
        property_element = root.find('property')
        
        # Check for giataId attribute and set giata_id to that value if present
        if property_element is not None and 'giataId' in property_element.attrib:
            giata_id = property_element.attrib['giataId']
        else:
            giata_id = 'no'
            
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred for {ratehawk_code}: {http_err}")
        giata_id = 'error'
    except ET.ParseError as xml_err:
        print(f"XML parse error for {ratehawk_code}: {xml_err}")
        giata_id = 'error'
    except Exception as err:
        print(f"Other error occurred for {ratehawk_code}: {err}")
        giata_id = 'error'
    
    # Update the 'giata_present' column with the actual giata id or fallback value
    df.at[index, 'giata_present'] = giata_id
    
    # Save the updated DataFrame immediately after processing each row
    df.to_excel('Umrahbooking_updated.xlsx', index=False)
    
    # Print a success message for the processed row
    print(f"Processed {ratehawk_code} successfully with giata id: {giata_id}")
    
    # Delay to avoid hitting rate limits
    time.sleep(1)

print("Processing complete. Updated file saved as 'Umrahbooking_updated.xlsx'")
# Out:
# Processed makkah_clock_royal_tower__a_fairmont_hotel successfully with giata id: 238369
# Processed swissotel_makkah successfully with giata id: 282258
# Processed rosh_rayhaan_by_rotana successfully with giata id: 571095
# Processed anwar_al_madinah_moevenpick_hotel successfully with giata id: 138287
# Processed pullman_zamzam_madina_ successfully with giata id: 427649
# Processed hotel_pullman_zamzam_makkah successfully with giata id: 129794
# Processed hyatt_regency_makkah successfully with giata id: 431847
# Processed address_jabal_omar_makkah successfully with giata id: 1375247
# Processed voco_makkah successfully with giata id: 1193729
# Processed millennium_makkah_al_naseem successfully with giata id: 1039856
# Processed joudyan_hotel successfully with giata id: 1332109
# Processed riyadh_marriott_hotel successfully with giata id: 431846
# Processed aloft_dhahran successfully with giata id: 594100
# Processed shaza_al_madina successfully with giata id: 244304
# Processed suite_novotel_riyadh_olaya successfully with giata id: 537594
# Processed odst_al_madinah_hotel successfully with giata id: 898886
# Processed al_kiswah_towers_hotel successfully with giata id: 554904
# Processed intercontinental_jeddah successfully with giata id: 75475
# Processed m_hotel_makkah_by_millennium successfully with giata id: 655454
# Processed shaza_riyadh successfully with giata id: 983510
# Processed saja_al_madinah_hotel successfully with giata id: 733368
# Processed holiday_inn_makkah_al_aziziah_2 successfully with giata id: 554894
# Processed anjum_hotel__makkah successfully with giata id: 417799
# Processed zowar_international successfully with giata id: 424211
# Processed four_points_by_sheraton_makkah_al_naseem successfully with giata id: 898860
# Processed courtyard_riyadh_diplomatic_quarter successfully with giata id: 282043
# Processed jeddah_sheraton_hotel successfully with giata id: 129789
# Processed novotel_makkah_thaker_city successfully with giata id: 1352498
# Processed aloft_riyadh_hotel successfully with giata id: 593394
# Processed jeddah_marriott_hotel_madinah_road successfully with giata id: 1332010
# Processed ibis_riyadh_olaya_street successfully with giata id: 301970
# Processed bay_la_sun_hotel_and_marina_ successfully with giata id: 469311
# Processed madareem_crown_hotel successfully with giata id: 128892
# Processed courtyard_by_marriott_riyadh_northern_ring_road successfully with giata id: 1275608
# Processed hyatt_regency_riyadh_olaya successfully with giata id: 641888
# Processed al_manakha_rotana_madinah successfully with giata id: 1425020
# Processed the_ritzcarlton_jeddah successfully with giata id: 682771
# Processed elaf_ajyad_ successfully with giata id: 133098
# Processed jeddah_hilton successfully with giata id: 66470
# Processed kempinski_al_othman_hotel_al_khobar successfully with giata id: 370835
# Processed top_riyadh_palace_hotel_2 successfully with giata id: 107322
# Processed hilton_suites_makkah successfully with giata id: 366601
# Processed raffles_makkah_palace successfully with giata id: 238368
# Processed dara_hotel_qurtubah successfully with giata id: 1302606
# Processed makkah_marriott_hotel_2 successfully with giata id: 413057
# Processed assila_hotel successfully with giata id: 560328
# Processed le_meridien_makkah_2 successfully with giata id: 129795
# Processed al_marwa_rayhaan_makkah successfully with giata id: 204074
# Processed myrtle_al_sahafa successfully with giata id: 1360238
# Processed elaf_kinda_hotel successfully with giata id: 110889
# Processed holiday_inn_riyadh_izdih successfully with giata id: 227091
# Processed hilton_makkah_convention_hotel successfully with giata id: 675736
# Processed braira_al_nakhil successfully with giata id: 1006295
# Processed sheraton_makkah_jabal_al_kaaba successfully with giata id: 668713
# Processed courtyard_riyadh_olaya successfully with giata id: 625708
# Processed ibis_jeddah_city_center successfully with giata id: 1244470
# Processed movenpick_hotel_and_residences_riyadh successfully with giata id: 1320848
# Processed centro_salama_jeddah_by_rotana successfully with giata id: 864305
# Processed crowne_plaza_jeddah successfully with giata id: 106516
# Processed joudyan_jeddah_red_sea_mall successfully with giata id: 234604
# Processed dar_al_eiman_royal_hotel successfully with giata id: 450570
# Processed doubletree_by_hilton_makkah_jabal_omar successfully with giata id: 369801
# Processed radisson_blu_hotel_riyadh successfully with giata id: 67716
# Processed movenpick_hotel_residence_hajar_tower_makkah_2 successfully with giata id: 234585
# Processed four_points_by_sheraton_jeddah_corniche successfully with giata id: 1331796
# Processed hala_inn successfully with giata id: 929021
# Processed hilton_garden_inn_riyadh_financial_district_2 successfully with giata id: 1275529
# Processed clarion_hotel_jeddah_airport successfully with giata id: 1331497
# Processed sheraton_riyadh_hotel_towers successfully with giata id: 77337
# Processed crowne_plaza_riyadh_itcc successfully with giata id: 539990
# Processed braira_al_yarmouk_hotel successfully with giata id: 1302773
# Processed executives_hotel__olaya successfully with giata id: 203214
# Processed sheraton_dammam_hotel_and_towers successfully with giata id: 129780
# Processed le_meridien_al_khobar_3 successfully with giata id: 108390
# Processed dallah_taibah_hotel successfully with giata id: 465687
# Processed grand_millennium_gizan_hotel successfully with giata id: 1305790
# Processed manazeli_al_corniche_hotel successfully with giata id: 973289
# Processed swissotel_al_maqam_makkah_2 successfully with giata id: 607973
# Processed golden_tulip_qasr_al_nasiriah successfully with giata id: 102360
# Processed le_meridien_medina successfully with giata id: 108421
# Processed centro_waha successfully with giata id: 687755
# Processed al_ebaa_hotel successfully with giata id: 1364832
# Processed dar_al_iman_intercontinental successfully with giata id: 138380
# Processed centro_olaya successfully with giata id: 959146
# Processed braira_dammam_hotel successfully with giata id: 865266
# Processed makarim_ajyad_makkah_hotel successfully with giata id: 133097
# Processed golden_tulip_hail successfully with giata id: 209873
# Processed ramada_riyadh_2 successfully with giata id: 419853
# Processed braira_qurtubah_riyadh successfully with giata id: 733539
# Processed boudl_abha successfully with giata id: 133089
# Processed plaza_inn_olaya successfully with giata id: 427647
# Processed intercontinental_riyadh successfully with giata id: 102361
# Processed swiss_international_royal_hotel_riyadh successfully with giata id: 664658
# Processed carawan_al_fahad_hotel successfully with giata id: 418950
# Processed ramada_encore_al_khobar_olaya successfully with giata id: 680575
# Processed ramada_by_wyndham_riyadh_king_fahd_road successfully with giata id: 1364842
# Processed park_inn_by_radisson_riyadh successfully with giata id: 1273469
# Processed movenpick_hotel_riyadh_2 successfully with giata id: 391325
# Processed best_western_plus_fursan_hotel successfully with giata id: 680569
# Processed melissa_hotel_riyadh successfully with giata id: 639491
# Processed dar_al_taqwa_hotel successfully with giata id: 143209
# Processed movenpick_hotel_jeddah successfully with giata id: 76948
# Processed centro_shaheen successfully with giata id: 581322
# Processed majlis_grand_mercure_medina successfully with giata id: 406739
# Processed m_hotel_al_dana_makkah_by_millennium successfully with giata id: 922703
# Processed iris_boutique_granada successfully with giata id: 1291129
# Processed andalusia_hotel_ex_golden_tulip_andalusia_hotel successfully with giata id: 107275
# Processed vittori_palace_hotel_residence successfully with giata id: 1279138
# Processed zaha_al_madina_hotel_2 successfully with giata id: 1354935
# Processed hdb_hotel_financal_district successfully with giata id: 1352905
# Processed art_view_hotel successfully with giata id: 1294179
# Processed grand_hyatt_al_khobar successfully with giata id: 1275516
# Processed burj_rafal_hotel_kempinski successfully with giata id: 391316
# Processed radisson_blu_hotel_riyadh_convention_and_exhibition_center successfully with giata id: 1284035
# Processed fairmont_riyadh successfully with giata id: 689034
# Processed al_waha_palace_hotel successfully with giata id: 221054
# Processed ibis_styles_makkah_opening_january_2017 successfully with giata id: 678171
# Processed braira_al_ahsa successfully with giata id: 1397780
# Processed mercure_jeddah_al_hamra successfully with giata id: 406738
# Processed wyndham_garden_dammam successfully with giata id: 977484
# Processed le_meridien_towers_makkah successfully with giata id: 138311
# Processed shaza_makkah successfully with giata id: 754661
# Processed olian_hotel successfully with giata id: 707942
# Processed intercontinental_dar_al_hijra_madinah successfully with giata id: 111734
# Processed rest_night_hotel_suites__al_nafal successfully with giata id: 527119
# Processed park_inn_by_radisson_makkah_al_naseem successfully with giata id: 678133
# Processed radisson_blu_plaza_jeddah successfully with giata id: 434371
# Processed the_business_hotel successfully with giata id: 431175
# Processed grand_mayral_hotel_ successfully with giata id: 470884
# Processed riyadh_airport_marriott_hotel successfully with giata id: 274867
# Processed marvelous_hotel successfully with giata id: 1375700
# Processed novotel_jazan_hotel successfully with giata id: 860538
# Processed madinah_hilton successfully with giata id: 66471
# Processed cristal_amaken_hotel successfully with giata id: 1016089
# Processed holiday_inn_riyadh_the_business_district successfully with giata id: 1400244
# Processed tiara_hotel_riyadh successfully with giata id: 431178
# Processed grand_plaza_hotel_2 successfully with giata id: 405897
# Processed elaf_bakkah_hotel successfully with giata id: 424497
# Processed holiday_villa_hail_hotel successfully with giata id: 1232260
# Processed conrad_makkah successfully with giata id: 369800
# Processed narcissus_hotel_and_residence successfully with giata id: 427646
# Processed the_ritz_carlton_riyadh successfully with giata id: 259720
# Processed hilton_garden_inn_al_khobar_2 successfully with giata id: 689423
# Processed doubletree_by_hilton_hotel_riyadh__al_muroj_business_gate successfully with giata id: 406027
# Processed golden_tulip_dammam_corniche_hotel successfully with giata id: 405227
# Processed hotel_jumeirah_jabal_omar_makkah successfully with giata id: 1392037
# Processed ibis_jeddah_malik_road successfully with giata id: 962147
# Processed hdb_sahafa successfully with giata id: 1307378
# Processed gardino_hotel_residence successfully with giata id: 1318008
# Processed grand_plaza_gulf_hotel successfully with giata id: 570294
# Processed radisson_blu_hotel_jeddah_corniche successfully with giata id: 731991
# Processed radisson_blu_hotel_jeddah_al_salam successfully with giata id: 689170
# Processed le_meridien_riyadh successfully with giata id: 1275413
# Processed comfort_hotel_jeddah_king_road successfully with giata id: 1331774
# Processed novotel_suites_riyadh_dyar_2 successfully with giata id: 431491
# Processed movenpick_hotel_tahlia_jeddah successfully with giata id: 977113
# Processed the_hotel_galleria_by_elaf successfully with giata id: 740251
# Processed residence_inn_by_marriott_dammam successfully with giata id: 1331999
# Processed staybridge_suites_al_khobar successfully with giata id: 884021
# Processed marriott_riyadh_diplomatic_quarter successfully with giata id: 1032452
# Processed tulip_inn_riyadh successfully with giata id: 223625
# Processed four_points_by_sheraton_riyadh_khaldia successfully with giata id: 274865
# Processed voyage_hotel_5 successfully with giata id: 629098
# Processed mira_business_hotel successfully with giata id: no
# Processed grand_plaza_hotelking_fahad_riyadh successfully with giata id: 1294236
# Processed four_seasons_hotel_riyadh successfully with giata id: 129801
# Processed copthorne_makkah_al_naseem successfully with giata id: 1011298
# Processed crowne_plaza_madinah successfully with giata id: 296249
# Processed jareed_riyadh successfully with giata id: 1331894
# Processed cantonal_hotel_by_warwick successfully with giata id: 1364977
# Processed cloud7_residence_alula successfully with giata id: 1396774
# Processed sidrathul_aaliya_hotel successfully with giata id: 865251
# Processed millennium_madinah_airport successfully with giata id: 878451
# Processed holiday_inn_riyadh_al_qasr successfully with giata id: 76947
# Processed golden_ship_hotel_2 successfully with giata id: 1318006
# Processed novotel_jeddah_tahlia successfully with giata id: 593657
# Processed crowne_plaza_hotel_al_khobar successfully with giata id: 240365
# Processed almuhaidb_residence_abha successfully with giata id: 898935
# Processed dar_al_tawheed_intercontinental_ successfully with giata id: 111812
# Processed courtyard_jazan_by_marriott successfully with giata id: 409975
# Processed habitas_alula successfully with giata id: 1304632
# Processed radisson_blu_hotel_riyadh_qurtuba successfully with giata id: 1284026
# Processed radisson_riyadh_airport successfully with giata id: 1284012
# Processed best_western_plus_buraidah successfully with giata id: 649676
# Processed salsabil_by_warwick successfully with giata id: 861400
# Processed ewaa_express successfully with giata id: 1319590
# Processed elaf_al_taqwa_hotel successfully with giata id: 1344380
# Processed prime_hotel_al_hamra_jeddah successfully with giata id: 691940
# Processed y_platinum successfully with giata id: 1294241
# Processed views_hotel_residences successfully with giata id: 1028246
# Processed ewaa_express_hotel_buraydah successfully with giata id: 1099764
# Processed makarim_umm_alqura_hotel successfully with giata id: 275284
# Processed hilton_riyadh_hotel_residences successfully with giata id: 682167
# Processed zaha_al_munawara_hotel successfully with giata id: 906260
# Processed citadines_abha successfully with giata id: 1351582
# Processed crowne_plaza_riyadh_minhal successfully with giata id: 129800
# Processed ramada_continental_jeddah successfully with giata id: 133094
# Processed innyar_hotel successfully with giata id: 1348547
# Processed swissotel_living_jeddah successfully with giata id: 1347964
# Processed al_shohada_hotel successfully with giata id: 138018
# Processed coral_al_madinah_hotel successfully with giata id: 986627
# Processed al_mashreq_boutique_hotel successfully with giata id: 417795
# Processed mansard_riyadh_a_radisson_collection_hotel_2 successfully with giata id: 1284054
# Processed park_inn_by_radisson_al_khobar successfully with giata id: 215059
# Processed intercontinental_taif successfully with giata id: 108060
# Processed mora_hotel_3 successfully with giata id: 1231414
# Processed emaar_elite_hotel successfully with giata id: 1391204
# Processed jeddah_grand_beach_hotel successfully with giata id: 1139555
# Processed mirnian successfully with giata id: 1364735
# Processed crown_rose_hotel successfully with giata id: 1179624
# Processed artal_taiba_hotel successfully with giata id: 1417183
# Processed holiday_jazan_hotel successfully with giata id: 431849
# Processed novotel_riyadh_sahafa_opening_march_2024 successfully with giata id: 1430719
# Processed park_inn_by_radisson_jeddah_madinah_road successfully with giata id: 1243424
# Processed crowne_plaza_jeddah_al_salam successfully with giata id: 999706
# Processed coral_suliemaniah_2 successfully with giata id: 233759
# Processed velvet_hotel_4 successfully with giata id: 808796
# Processed grand_millennium_tabuk successfully with giata id: 1294210
# Processed grand_plaza_hoteljazan successfully with giata id: 1331672
# Processed park_inn_by_radisson_dammam successfully with giata id: 475186
# Processed al_faisaliah_hotel_a_rosewood_hotel successfully with giata id: 133106
# Processed al_eiman_royal_hotel successfully with giata id: 467011
# Processed emaar_andalusia successfully with giata id: 1396763
# Processed boudl_al_sahafa successfully with giata id: 707642
# Processed grand_plaza_dhabab_hotel successfully with giata id: 543775
# Processed holiday_inn_tabuk successfully with giata id: 431853
# Processed jasmine_garden_hotel successfully with giata id: 1418722
# Processed millennia_olaya_hotel_ successfully with giata id: 458330
# Processed myrtle_2 successfully with giata id: 1236939
# Processed aber_khamis_mushait successfully with giata id: 1331585
# Processed coral_dhahran_hotel successfully with giata id: 244310
# Processed super_8_al_riyadh_2 successfully with giata id: 411714
# Processed banyan_tree_alula successfully with giata id: 1317538
# Processed holiday_inn_resort_half_moon_bay successfully with giata id: 107772
# Processed elaf_al_mashaer_hotel successfully with giata id: 234584
# Processed aber_altakhassusi_105 successfully with giata id: 1294164
# Processed tulip_inn_al_reef successfully with giata id: 236737
# Processed sofitel_al_khobar_the_corniche successfully with giata id: 237173
# Processed palms_lily_hotel_suites successfully with giata id: 629284
# Processed intour_qurtoba successfully with giata id: 707676
# Processed alhyatt_jeddah_continental_hotel successfully with giata id: 244247
# Processed charli_hotel_jeddah successfully with giata id: 1428308
# Processed fairmont_ramla_riyadh_opening_soon successfully with giata id: 1291137
# Processed karem_riyadh_residence_hotel_apartment successfully with giata id: 1338485
# Processed _0x25d12 successfully with giata id: 517174
# Processed warwick_riyadh_hotel successfully with giata id: 1282553
# Processed millennium_hail_hotel successfully with giata id: 575769
# Processed habitat_hotel_al_khobar successfully with giata id: 515496
# Processed _0x37d78 successfully with giata id: 625680
# Processed casablanca_grand_hotel successfully with giata id: 637969
# Processed ewaa_express_hotelal_olaya successfully with giata id: 467214
# Processed waqf_outhman_bin_affan_hotel successfully with giata id: 1433256
# Processed marriott_executive_apartments_riyadh_makarim successfully with giata id: 383043
# Processed cloud_7_residence_alula successfully with giata id: 1396774
# Processed al_ahsa_intercontinental successfully with giata id: 137502
# Processed boudl_taif successfully with giata id: 371092
# Processed gulanar_hotel successfully with giata id: 889721
# Processed narcissus_the_royal_hotel successfully with giata id: 1428454
# Processed mena_hotel_tabuk successfully with giata id: 871875
# Processed voco_al_khobar successfully with giata id: 1207016
# Processed boudl_buraydah successfully with giata id: 244245
# Processed sas_hotel successfully with giata id: 431176
# Processed holiday_inn_suites_al_khobar_an_ihg_hotel successfully with giata id: 1399257
# Processed orchid_hotel_9 successfully with giata id: 265776
# Processed holiday_inn_jeddah_gateway successfully with giata id: 429632
# Processed best_western_plus_riyadh successfully with giata id: 431343
# Processed rabigh_park_hotel successfully with giata id: 707838
# Processed fraser_suites_riyadh successfully with giata id: 720162
# Processed luxury_night_hotel successfully with giata id: 1428534
# Processed beautat_hotel successfully with giata id: 803737
# Processed retaj_al_rayyan_makkah successfully with giata id: 604187
# Processed rosewood_corniche_4 successfully with giata id: 129784
# Processed al_haram_hotel_by_al_rawda successfully with giata id: 137490
# Processed boudl_wadi_aldawasir successfully with giata id: 1364902
# Processed boudl_alworoud successfully with giata id: 369572
# Processed al_faisaliah_resort_spa successfully with giata id: 752709
# Processed park_inn_by_radisson_jeddah_madinah_road_2 successfully with giata id: 1243424
# Processed anan_hotel_2 successfully with giata id: 1331646
# Processed intercontinental_al_jubail successfully with giata id: 108046
# Processed seven_gardens_hotel_2 successfully with giata id: 1420211
# Processed novotel_dammam_business_park successfully with giata id: 259730
# Processed swiss_spirit_metropolitan successfully with giata id: 688460
# Processed intercityhotel_riyadh_malaz successfully with giata id: 767587
# Processed al_muteb_suites_al_falah_1 successfully with giata id: 1374803
# Processed address_al_hamra successfully with giata id: 959284
# Processed armada_hotel_jazan successfully with giata id: 927525
# Processed the_house_hotel_jeddah_city_yard successfully with giata id: 1282635
# Processed al_aqeeq_hotel__by_al_rawda successfully with giata id: 527090
# Processed enala_tabuk successfully with giata id: 1331717
# Processed oyo_582_al_tamayoz_al_raqi_al_salamah successfully with giata id: 1320406
# Processed makarim_mina_hotel successfully with giata id: 468069
# Processed al_muhaidb_residence_al_ahsa successfully with giata id: 720456
# Processed holiday_inn_jeddah_corniche successfully with giata id: 1422949
# Processed ascott_rafal_olaya_riyadh_4 successfully with giata id: 556472
# Processed movenpick_hotel_al_khobar successfully with giata id: 138295
# Processed the_st_regis_riyadh_2 successfully with giata id: 1372053
# Processed qasr_alshamal_hotel successfully with giata id: 1291060
# Processed le_meridien_jeddah successfully with giata id: 75479
# Processed abha_palace successfully with giata id: 275231
# Processed jazalah successfully with giata id: no
# Processed al_rayah_hotel successfully with giata id: 1433020
# Processed badr_hotel successfully with giata id: 465497
# Processed ibis_yanbu_ successfully with giata id: 406740
# Processed almuhaidb_sudair successfully with giata id: 681909
# Processed hilton_riyadh_olaya successfully with giata id: 1401036
# Processed al_hamra_palace_hotel_riyadh_3 successfully with giata id: 244307
# Processed golden_dune_hotel successfully with giata id: 922804
# Processed emaar_al_khlil successfully with giata id: 1414820
# Processed hafawah_suites successfully with giata id: 898907
# Processed holiday_khaleej successfully with giata id: 707312
# Processed new_madinah_hotel successfully with giata id: 244302
# Processed niyaf_hotel_suites_2 successfully with giata id: 889693
# Processed swiss_international_al_hamra_dammam successfully with giata id: 98458
# Processed msharef_al_moden_suites successfully with giata id: 707867
# Processed zaha_taiba_hotel successfully with giata id: 1390517
# Processed comfort_hotel_riyadh_olaya successfully with giata id: 1396443
# Processed marriott_executive_apartments_madinah successfully with giata id: 1082228
# Processed erfad_hotel successfully with giata id: 1433087
# Processed boudl_quraish successfully with giata id: 906091
# Processed renz_hotel successfully with giata id: 526950
# Processed rosalina_hotel successfully with giata id: 691910
# Processed concorde_dar_al_khair_hotel successfully with giata id: 720494
# Processed aber_unayzah successfully with giata id: 1236800
# Processed holiday_inn_suites_jubail_taibah successfully with giata id: 1275533
# Processed boudl_mahayel_aseer successfully with giata id: 629107
# Processed hilton_garden_inn_tabuk successfully with giata id: 429634
# Processed radisson_blu_yanbu successfully with giata id: 67859
# Processed hilton_garden_inn_al_jubail successfully with giata id: 983490
# Processed golden_new_al_safa successfully with giata id: 1406012
# Processed intercontinental_al_khobar successfully with giata id: 138467
# Processed granada_palace_inn successfully with giata id: 1417390
# Processed central_park_hotel_bisha_fndq_sntrl_brk_bysh successfully with giata id: no
# Processed aerotel_jeddah_transit_hotel_in_terminal_1 successfully with giata id: 1427753
# Processed al_murjan_crom_hotel successfully with giata id: 927610
# Processed iris_boutique_narjis successfully with giata id: 1428530
# Processed braira_al_wezarat successfully with giata id: 738833
# Processed al_farhan_suites_jeddah_ successfully with giata id: 543866
# Processed executives_hotel_al_azizia successfully with giata id: 274874
# Processed radisson_blu_hotel_residence_riyadh_diplomatic_quarters successfully with giata id: 1023538
# Processed park_inn_by_radisson_makkah_aziziyah_2 successfully with giata id: 1105470
# Processed boudl_al_sulimanyah successfully with giata id: 1379188
# Processed taba_alsalam_hotel successfully with giata id: 733768
# Processed al_eairy_furnished_apts_al_madinah_14 successfully with giata id: 883523
# Processed al_eairy_furnished_apt_al_madinah_1 successfully with giata id: 889447
# Processed grand_zowar_hotel successfully with giata id: 1132184
# Processed ozone_hotel_3 successfully with giata id: 1318247
# Processed grand_makkah_hotel successfully with giata id: 646988
# Processed oberoi_2 successfully with giata id: 138500
# Processed mandarin_hotel_apartments successfully with giata id: 667791
# Processed movenpick_hotel_qassim successfully with giata id: 138429
# Processed gloria_inn successfully with giata id: 604932
# Processed citadines_al_salamah_jeddah_2 successfully with giata id: 431852
# Processed boudl_gardenia_resort successfully with giata id: 464903
# Processed w_platinum_2 successfully with giata id: 1294233
# Processed tulip_inn_yanbu_2 successfully with giata id: 570765
# Processed the_proud_hotel_2 successfully with giata id: 1306969
# Processed leader_al_muna_kareem_hotel_2 successfully with giata id: 234617
# Processed hayat_heraa_suites successfully with giata id: 581320
# Processed myan_al_urubah_hotel successfully with giata id: 707949
# Processed zaha_hotel successfully with giata id: 906260
# Processed shangrila_jeddah successfully with giata id: 1305722
# Processed holiday_inn_riyadholaya successfully with giata id: 59988
# Processed blue_inn_2 successfully with giata id: 946815
# Processed askant_al_hafayer successfully with giata id: 1427626
# Processed al_azhar_hotel_jeddah successfully with giata id: 233757
# Processed awaliv_international_hotel successfully with giata id: 276614
# Processed emerald_hotel_17 successfully with giata id: 1302604
# Processed aram_hotel_almeshael_exit_18 successfully with giata id: 1359937
# Processed ramada_hotel_and_suites_dammam successfully with giata id: 681172
# Processed boudl_alfayhaa_2 successfully with giata id: 133102
# Processed ewaa_express_hotelal_shati successfully with giata id: 1433243
# Processed grand_al_massa_hotel successfully with giata id: 275285
# Processed jazan_inn successfully with giata id: 293798
# Processed staybridge_suites_al_khobar_city_an_ihg_hotel successfully with giata id: 1314134
# Processed golden_andalus_hotel_abha successfully with giata id: 1406325
# Processed al_eiman_taibah successfully with giata id: 465328
# Processed al_borg_al_watheer successfully with giata id: 466295
# Processed emaar_mektan successfully with giata id: 470647
# Processed cloud_city_hotel successfully with giata id: 1283423
# Processed radisson_blu_residence_dhahran successfully with giata id: 668038
# Processed al_andlus_palace_2_hotel_kurban_fndq_qsr_lndls_2_qrbn successfully with giata id: no
# Processed almuhaidb_residence_aldawadmi successfully with giata id: 1269372
# Processed motiara_hotel_la_valle_mall successfully with giata id: 1232337
# Processed _0x3d4f5 successfully with giata id: 925867
# Processed ewaa_express_hotel_khorais successfully with giata id: 1294198
# Processed nivel_hotel successfully with giata id: 1364737
# Processed enala_hotel_umluj successfully with giata id: 1432479
# Processed park_hyatt_jeddah__marina_club_and_spa successfully with giata id: 215055
# Processed boudl_palestine successfully with giata id: 503853
# Processed aber_103_al_mounisya successfully with giata id: 983506
# Processed the_westin_jeddah successfully with giata id: 76946
# Processed dar_al_eiman_grand successfully with giata id: 604929
# Processed boudl_al_munsiyah successfully with giata id: 715051
# Processed ewaa_express_hotel_gaber successfully with giata id: 1237615
# Processed iris_boutique_taif_heart successfully with giata id: 1291128
# Processed platinum_boutique_al_naeem successfully with giata id: 629339
# Processed al_saha_hotel successfully with giata id: 466218
# Processed flavor successfully with giata id: 1420057
# Processed iridium_70_hotel successfully with giata id: 1016233
# Processed ramada_al_qassim_hotel_and_suites successfully with giata id: 162422
# Processed qasr_al_sahab successfully with giata id: 466285
# Processed al_massa_hotel successfully with giata id: 1449642
# Processed royal_casablanca successfully with giata id: 275274
# Processed midan_hotel_ successfully with giata id: 468145
# Processed millennium_al_aqeeq_hotel successfully with giata id: 424515
# Processed sarwat_park_hotel_riyadhdiplomatic_quarter_fndq_srwt_brk_lrydhy_lsfrt successfully with giata id: no
# Processed copthorne_hotel_riyadh successfully with giata id: 570723
# Processed habitat_hotel successfully with giata id: 129786
# Processed holiday_inn_al_khobar_3 successfully with giata id: 107605
# Processed novotel_al_anoud successfully with giata id: 162416
# Processed radisson_blu_resort_al_khobar_half_moon_bay successfully with giata id: 719249
# Processed riyadh_diplomatic_quarter_marriott_executive_apartments successfully with giata id: 1111996
# Processed dara_alrayyan_hotel successfully with giata id: 1318081
# Processed kyona_alaziziyah successfully with giata id: 1332050
# Processed boudl_majmaa_apartment_2 successfully with giata id: 527091
# Processed season_star_hotel successfully with giata id: 1291104
# Processed accor_palace_riyadh successfully with giata id: 1348547
# Processed park_inn_by_radisson_hotel_apartments_dammam_industrial_city successfully with giata id: 758084
# Processed park_inn_by_radisson_makkah_aziziyah successfully with giata id: 1105470
# Processed park_inn_by_radisson_jubail_industrial_city successfully with giata id: 800135
# Processed kyona_purpel successfully with giata id: 1332088
# Processed diamond_suites_8 successfully with giata id: 1359975
# Processed wa_hotel_3 successfully with giata id: 1331440
# Processed prime_al_corniche_hotel successfully with giata id: 1364892
# Processed grand_plaza_al_madina_ex_al_salhiya_tibah successfully with giata id: 1365508
# Processed hdb_resort_spa_alkhobar successfully with giata id: 1428576
# Processed golden_gewan_hotel_abha successfully with giata id: 1396750
# Processed mercure_makkah_aziziah successfully with giata id: 1422128
# Processed saja_hotels_makkah successfully with giata id: 1433106
# Processed ascott_corniche_al_khobar successfully with giata id: 1105506
# Processed centro_corniche_al_khobar successfully with giata id: 1231024
# Processed naviti_warwick_dammam_2 successfully with giata id: 1023471
# Processed al_ansar_golden_tulip successfully with giata id: 543348
# Processed diwan_residence_hotel_alnaeem successfully with giata id: 859670
# Processed makeen_homes_by_warwick successfully with giata id: 999402
# Processed le_park_concord_rabwah_riyadh successfully with giata id: 1316096
# Processed raytna_al_wadi successfully with giata id: 1364755
# Processed qasr_lazurd successfully with giata id: 741179
# Processed grand_plaza_badr_al_maqam_ma successfully with giata id: 1428629
# Processed golden_bujari_hotel_bisha successfully with giata id: 1428442
# Processed boudl_almaidan successfully with giata id: 138177
# Processed elite_of_elite successfully with giata id: 1294284
# Processed oyo_273_star_yanbu_hotel_suites successfully with giata id: 1105539
# Processed areen_airport_hotel successfully with giata id: 1406878
# Processed the_jeddah_edition successfully with giata id: 1424578
# Processed emaar_al_dewan_al_sud successfully with giata id: 1428588
# Processed duset_hotel_suites successfully with giata id: 646862
# Processed hayat_alriyadh_hotel successfully with giata id: 1302691
# Processed boudl_al_wadi_hotel successfully with giata id: 1232317
# Processed swiss_in_park_tabuk successfully with giata id: 1111029
# Processed ewaa_express_hotel_al_jouf successfully with giata id: 1394154
# Processed khabti_grand_hotel successfully with giata id: 1383248
# Processed artal_international_hotel successfully with giata id: 1426032
# Processed al_mokhtara_diamond successfully with giata id: 1451337
# Processed holiday_inn_al_khobar_corniche successfully with giata id: 210543
# Processed golden_tulip_riyadh successfully with giata id: 1304645
# Processed radisson_blu_resort_jizan successfully with giata id: 433099
# Processed boudl_al_qasr successfully with giata id: 471193
# Processed burj_al_hayat_furnished_suites successfully with giata id: 545755
# Processed comfort_inn_163 successfully with giata id: 274863
# Processed dana_rayhaan_by_rotana successfully with giata id: 1244505
# Processed ramada_by_wyndham_al_khobar_king_abdullah_street successfully with giata id: 245542
# Processed rio_hotel_olaya successfully with giata id: 1433437
# Processed paradise_inn_jeddah successfully with giata id: 1428506
# Processed holiday_inn_najran successfully with giata id: 107748
# Processed waad_al_ula_hotel successfully with giata id: 1005498
# Processed emaar_al_manar successfully with giata id: 1391240
# Processed ross_hotel successfully with giata id: 1427254
# Processed al_farhan_hotel_suites_al_aqiq_ successfully with giata id: 651215
# Processed ascott_sari_jeddah_2 successfully with giata id: 431851
# Processed alreem_hotel successfully with giata id: 604202
# Processed almuhaidb_residence successfully with giata id: 752475
# Processed almuhaidb_furnished_units_king_abdulaziz successfully with giata id: 898894
# Processed centro_corniche_al_khobar_by_rotana successfully with giata id: 1231024
# Processed shada_hotel_shati successfully with giata id: 1278687
# Processed al_muteb_suites_al_najah successfully with giata id: 1418576
# Processed hampton_by_hilton_sharma successfully with giata id: 1430068
# Processed hyatt_place_riyadh_al_sulaimania successfully with giata id: 875263
# Processed al_eairy_furnished_apartments_jizan_1 successfully with giata id: 878177
# Processed somewhere_bliss successfully with giata id: 875520
# Processed aquila_hotel successfully with giata id: 925789
# Processed al_muteb_suites_al_ezdehar_2 successfully with giata id: 1364762
# Processed al_safwah_royale_orchid successfully with giata id: 417796
# Processed aber_102 successfully with giata id: 734289
# Processed aber_abha successfully with giata id: 1302774
# Processed basma_plaza successfully with giata id: 1406259
# Processed boudl_al_tahlia successfully with giata id: 133095
# Processed grand_park_hotel_7 successfully with giata id: 604930
# Processed awaliv_suites successfully with giata id: 276615
# Processed aber_101 successfully with giata id: 707693
# Processed faraj_al_madina_hotel successfully with giata id: 1315313
# Processed al_rayyan_towers_hotel_mecca1 successfully with giata id: 1428632
# Processed hamsa_fajr_furnished_apartments successfully with giata id: no
# Processed park_inn_by_radisson_makkah_thakher_east successfully with giata id: 1430044
# Processed dar_al_wedad_hotel successfully with giata id: 732707
# Processed city_view_hotel_by_crown_town successfully with giata id: 1088979
# Processed golden_tulip_abha successfully with giata id: 1406275
# Processed skyline_hotel_suites_3 successfully with giata id: 1426347
# Processed radisson_hotel_residence_riyadh_olaya successfully with giata id: 1432050
# Processed al_muteb_suites_al_yarmouk_2 successfully with giata id: 1406489
# Processed emaar_grand_hotel successfully with giata id: 604929
# Processed golden_alareen successfully with giata id: 1396770
# Processed holiday_inn_meydan successfully with giata id: 288339
# Processed refaaf_al_azizia_hotel successfully with giata id: 465061
# Processed alwateen_hotel successfully with giata id: 1418575
# Processed sweet_land_hotel successfully with giata id: 1397490
# Processed golden_tulip_al_zahabi successfully with giata id: 326552
# Processed narcissus_resort_spa_obhur_jeddah successfully with giata id: 856858
# Processed triple_tree successfully with giata id: 707906
# Processed al_eairy_furnished_apt_al_madinah_3 successfully with giata id: 882777
# Processed almaali_hotel successfully with giata id: 1294091
# Processed merfal_hotel_apartment_royal successfully with giata id: 550735
# Processed tulip_plaza_hafr_al_batin successfully with giata id: 1430034
# Processed wajiht_najran successfully with giata id: no
# Processed rest_night_hotel_apartment__al_hamra successfully with giata id: 503872
# Processed almuhaidb_al_olaya_3 successfully with giata id: 658125
# Processed almuhaidb_residence_al_jubail successfully with giata id: 707986
# Processed rest_night_hotel_suites_al_nafal successfully with giata id: 527119
# Processed tulip_inn_al_dar_rawafed successfully with giata id: 1023042
# Processed boudl_alfayhaa_7 successfully with giata id: 133102
# Processed al_farhan_hotel_suites_exit_15 successfully with giata id: 451746
# Processed makkah_hotel successfully with giata id: 66472
# Processed hyatt_buyutat_apartment successfully with giata id: 503869
# Processed naviti_warwick_dammam successfully with giata id: 1023471
# Processed rafa_al_nuzhah successfully with giata id: 921722
# Processed donatello_hotel_2 successfully with giata id: 1294117
# Processed doubletree_by_hilton_riyadh_financial_district_hotelsuites successfully with giata id: 1285947
# Processed oyo_589_lavina_house successfully with giata id: 1315799
# Processed al_majeedi_arac_suites_ successfully with giata id: 1399815
# Processed movenpick_hotel_city_star_jeddah successfully with giata id: 560525
# Processed lafontaine_opal_hotel successfully with giata id: 1294177
# Processed shaden_resort_al_ulla successfully with giata id: 757439
# Processed nusk_al_hijrah_hotel successfully with giata id: 1428626

# %% [markdown]
# ### Here only take where Mapped = no

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
import time
from dotenv import load_dotenv
import os

load_dotenv()


GIATA_KEY = os.getenv("GIATA_API_key")

# Read the Excel file
df = pd.read_excel('Umrahbooking.xlsx')

# Ensure 'giata_present' column is of type string
df['giata_present'] = df['giata_present'].astype(str)

headers = {
    'Authorization': f'Basic {GIATA_KEY}'
}


for index, row in df.iterrows():
    if str(row['Mapped']).strip().lower() != 'no':
        print(f"Skipping {row['Ratehawk Code']} because Mapped is not 'no'")
        continue
    
    ratehawk_code = row['Ratehawk Code']
    url = f"https://multicodes.giatamedia.com/webservice/rest/1.0/properties/gds/ratehawk2/{ratehawk_code}"
    
    try:
        response = requests.post(url, headers=headers)
        response.raise_for_status()  # Raise exception for HTTP errors
        
        root = ET.fromstring(response.content)
        property_element = root.find('property')
        
        # Check for giataId attribute and set giata_id to that value if present
        if property_element is not None and 'giataId' in property_element.attrib:
            giata_id = property_element.attrib['giataId']
        else:
            giata_id = 'no'
            
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred for {ratehawk_code}: {http_err}")
        giata_id = 'error'
    except ET.ParseError as xml_err:
        print(f"XML parse error for {ratehawk_code}: {xml_err}")
        giata_id = 'error'
    except Exception as err:
        print(f"Other error occurred for {ratehawk_code}: {err}")
        giata_id = 'error'
    
    # Update the 'giata_present' column with the actual giata id or fallback value
    df.at[index, 'giata_present'] = giata_id
    
    # Save the updated DataFrame immediately after processing each row
    df.to_excel('Umrahbooking_updated.xlsx', index=False)
    
    # Print a success message for the processed row
    print(f"Processed {ratehawk_code} successfully with giata id: {giata_id}")
    
    # Delay to avoid hitting rate limits
    time.sleep(1)

print("Processing complete. Updated file saved as 'Umrahbooking_updated.xlsx'")
# Out:
# Skipping makkah_clock_royal_tower__a_fairmont_hotel because Mapped is not 'no'
# Skipping swissotel_makkah because Mapped is not 'no'
# Skipping rosh_rayhaan_by_rotana because Mapped is not 'no'
# Skipping anwar_al_madinah_moevenpick_hotel because Mapped is not 'no'
# Skipping pullman_zamzam_madina_ because Mapped is not 'no'
# Skipping hotel_pullman_zamzam_makkah because Mapped is not 'no'
# Skipping hyatt_regency_makkah because Mapped is not 'no'
# Skipping address_jabal_omar_makkah because Mapped is not 'no'
# Skipping voco_makkah because Mapped is not 'no'
# Skipping millennium_makkah_al_naseem because Mapped is not 'no'
# Skipping joudyan_hotel because Mapped is not 'no'
# Skipping riyadh_marriott_hotel because Mapped is not 'no'
# Skipping aloft_dhahran because Mapped is not 'no'
# Skipping shaza_al_madina because Mapped is not 'no'
# Skipping suite_novotel_riyadh_olaya because Mapped is not 'no'
# Skipping odst_al_madinah_hotel because Mapped is not 'no'
# Skipping al_kiswah_towers_hotel because Mapped is not 'no'
# Skipping intercontinental_jeddah because Mapped is not 'no'
# Skipping m_hotel_makkah_by_millennium because Mapped is not 'no'
# Skipping shaza_riyadh because Mapped is not 'no'
# Skipping saja_al_madinah_hotel because Mapped is not 'no'
# Skipping holiday_inn_makkah_al_aziziah_2 because Mapped is not 'no'
# Skipping anjum_hotel__makkah because Mapped is not 'no'
# Skipping zowar_international because Mapped is not 'no'
# Skipping four_points_by_sheraton_makkah_al_naseem because Mapped is not 'no'
# Skipping courtyard_riyadh_diplomatic_quarter because Mapped is not 'no'
# Skipping jeddah_sheraton_hotel because Mapped is not 'no'
# Skipping novotel_makkah_thaker_city because Mapped is not 'no'
# Skipping aloft_riyadh_hotel because Mapped is not 'no'
# Skipping jeddah_marriott_hotel_madinah_road because Mapped is not 'no'
# Skipping ibis_riyadh_olaya_street because Mapped is not 'no'
# Skipping bay_la_sun_hotel_and_marina_ because Mapped is not 'no'
# Skipping madareem_crown_hotel because Mapped is not 'no'
# Skipping courtyard_by_marriott_riyadh_northern_ring_road because Mapped is not 'no'
# Skipping hyatt_regency_riyadh_olaya because Mapped is not 'no'
# Skipping al_manakha_rotana_madinah because Mapped is not 'no'
# Skipping the_ritzcarlton_jeddah because Mapped is not 'no'
# Skipping elaf_ajyad_ because Mapped is not 'no'
# Skipping jeddah_hilton because Mapped is not 'no'
# Skipping kempinski_al_othman_hotel_al_khobar because Mapped is not 'no'
# Skipping top_riyadh_palace_hotel_2 because Mapped is not 'no'
# Skipping hilton_suites_makkah because Mapped is not 'no'
# Skipping raffles_makkah_palace because Mapped is not 'no'
# Skipping dara_hotel_qurtubah because Mapped is not 'no'
# Skipping makkah_marriott_hotel_2 because Mapped is not 'no'
# Skipping assila_hotel because Mapped is not 'no'
# Skipping le_meridien_makkah_2 because Mapped is not 'no'
# Skipping al_marwa_rayhaan_makkah because Mapped is not 'no'
# Skipping myrtle_al_sahafa because Mapped is not 'no'
# Skipping elaf_kinda_hotel because Mapped is not 'no'
# Skipping holiday_inn_riyadh_izdih because Mapped is not 'no'
# Skipping hilton_makkah_convention_hotel because Mapped is not 'no'
# Skipping braira_al_nakhil because Mapped is not 'no'
# Skipping sheraton_makkah_jabal_al_kaaba because Mapped is not 'no'
# Skipping courtyard_riyadh_olaya because Mapped is not 'no'
# Skipping ibis_jeddah_city_center because Mapped is not 'no'
# Skipping movenpick_hotel_and_residences_riyadh because Mapped is not 'no'
# Skipping centro_salama_jeddah_by_rotana because Mapped is not 'no'
# Skipping crowne_plaza_jeddah because Mapped is not 'no'
# Skipping joudyan_jeddah_red_sea_mall because Mapped is not 'no'
# Skipping dar_al_eiman_royal_hotel because Mapped is not 'no'
# Skipping doubletree_by_hilton_makkah_jabal_omar because Mapped is not 'no'
# Skipping radisson_blu_hotel_riyadh because Mapped is not 'no'
# Skipping movenpick_hotel_residence_hajar_tower_makkah_2 because Mapped is not 'no'
# Skipping four_points_by_sheraton_jeddah_corniche because Mapped is not 'no'
# Skipping hala_inn because Mapped is not 'no'
# Skipping hilton_garden_inn_riyadh_financial_district_2 because Mapped is not 'no'
# Skipping clarion_hotel_jeddah_airport because Mapped is not 'no'
# Skipping sheraton_riyadh_hotel_towers because Mapped is not 'no'
# Skipping crowne_plaza_riyadh_itcc because Mapped is not 'no'
# Skipping braira_al_yarmouk_hotel because Mapped is not 'no'
# Skipping executives_hotel__olaya because Mapped is not 'no'
# Skipping sheraton_dammam_hotel_and_towers because Mapped is not 'no'
# Skipping le_meridien_al_khobar_3 because Mapped is not 'no'
# Skipping dallah_taibah_hotel because Mapped is not 'no'
# Skipping grand_millennium_gizan_hotel because Mapped is not 'no'
# Skipping manazeli_al_corniche_hotel because Mapped is not 'no'
# Skipping swissotel_al_maqam_makkah_2 because Mapped is not 'no'
# Skipping golden_tulip_qasr_al_nasiriah because Mapped is not 'no'
# Skipping le_meridien_medina because Mapped is not 'no'
# Skipping centro_waha because Mapped is not 'no'
# Skipping al_ebaa_hotel because Mapped is not 'no'
# Skipping dar_al_iman_intercontinental because Mapped is not 'no'
# Skipping centro_olaya because Mapped is not 'no'
# Skipping braira_dammam_hotel because Mapped is not 'no'
# Skipping makarim_ajyad_makkah_hotel because Mapped is not 'no'
# Skipping golden_tulip_hail because Mapped is not 'no'
# Skipping ramada_riyadh_2 because Mapped is not 'no'
# Skipping braira_qurtubah_riyadh because Mapped is not 'no'
# Skipping boudl_abha because Mapped is not 'no'
# Skipping plaza_inn_olaya because Mapped is not 'no'
# Skipping intercontinental_riyadh because Mapped is not 'no'
# Skipping swiss_international_royal_hotel_riyadh because Mapped is not 'no'
# Skipping carawan_al_fahad_hotel because Mapped is not 'no'
# Skipping ramada_encore_al_khobar_olaya because Mapped is not 'no'
# Skipping ramada_by_wyndham_riyadh_king_fahd_road because Mapped is not 'no'
# Skipping park_inn_by_radisson_riyadh because Mapped is not 'no'
# Skipping movenpick_hotel_riyadh_2 because Mapped is not 'no'
# Skipping best_western_plus_fursan_hotel because Mapped is not 'no'
# Skipping melissa_hotel_riyadh because Mapped is not 'no'
# Skipping dar_al_taqwa_hotel because Mapped is not 'no'
# Skipping movenpick_hotel_jeddah because Mapped is not 'no'
# Skipping centro_shaheen because Mapped is not 'no'
# Skipping majlis_grand_mercure_medina because Mapped is not 'no'
# Skipping m_hotel_al_dana_makkah_by_millennium because Mapped is not 'no'
# Skipping iris_boutique_granada because Mapped is not 'no'
# Skipping andalusia_hotel_ex_golden_tulip_andalusia_hotel because Mapped is not 'no'
# Skipping vittori_palace_hotel_residence because Mapped is not 'no'
# Skipping zaha_al_madina_hotel_2 because Mapped is not 'no'
# Skipping hdb_hotel_financal_district because Mapped is not 'no'
# Skipping art_view_hotel because Mapped is not 'no'
# Skipping grand_hyatt_al_khobar because Mapped is not 'no'
# Skipping burj_rafal_hotel_kempinski because Mapped is not 'no'
# Skipping radisson_blu_hotel_riyadh_convention_and_exhibition_center because Mapped is not 'no'
# Skipping fairmont_riyadh because Mapped is not 'no'
# Skipping al_waha_palace_hotel because Mapped is not 'no'
# Skipping ibis_styles_makkah_opening_january_2017 because Mapped is not 'no'
# Skipping braira_al_ahsa because Mapped is not 'no'
# Skipping mercure_jeddah_al_hamra because Mapped is not 'no'
# Skipping wyndham_garden_dammam because Mapped is not 'no'
# Skipping le_meridien_towers_makkah because Mapped is not 'no'
# Skipping shaza_makkah because Mapped is not 'no'
# Skipping olian_hotel because Mapped is not 'no'
# Skipping intercontinental_dar_al_hijra_madinah because Mapped is not 'no'
# Skipping rest_night_hotel_suites__al_nafal because Mapped is not 'no'
# Skipping park_inn_by_radisson_makkah_al_naseem because Mapped is not 'no'
# Skipping radisson_blu_plaza_jeddah because Mapped is not 'no'
# Skipping the_business_hotel because Mapped is not 'no'
# Skipping grand_mayral_hotel_ because Mapped is not 'no'
# Skipping riyadh_airport_marriott_hotel because Mapped is not 'no'
# Skipping marvelous_hotel because Mapped is not 'no'
# Skipping novotel_jazan_hotel because Mapped is not 'no'
# Skipping madinah_hilton because Mapped is not 'no'
# Skipping cristal_amaken_hotel because Mapped is not 'no'
# Skipping holiday_inn_riyadh_the_business_district because Mapped is not 'no'
# Skipping tiara_hotel_riyadh because Mapped is not 'no'
# Skipping grand_plaza_hotel_2 because Mapped is not 'no'
# Skipping elaf_bakkah_hotel because Mapped is not 'no'
# Skipping holiday_villa_hail_hotel because Mapped is not 'no'
# Skipping conrad_makkah because Mapped is not 'no'
# Skipping narcissus_hotel_and_residence because Mapped is not 'no'
# Skipping the_ritz_carlton_riyadh because Mapped is not 'no'
# Skipping hilton_garden_inn_al_khobar_2 because Mapped is not 'no'
# Skipping doubletree_by_hilton_hotel_riyadh__al_muroj_business_gate because Mapped is not 'no'
# Skipping golden_tulip_dammam_corniche_hotel because Mapped is not 'no'
# Skipping hotel_jumeirah_jabal_omar_makkah because Mapped is not 'no'
# Skipping ibis_jeddah_malik_road because Mapped is not 'no'
# Skipping hdb_sahafa because Mapped is not 'no'
# Skipping gardino_hotel_residence because Mapped is not 'no'
# Skipping grand_plaza_gulf_hotel because Mapped is not 'no'
# Skipping radisson_blu_hotel_jeddah_corniche because Mapped is not 'no'
# Skipping radisson_blu_hotel_jeddah_al_salam because Mapped is not 'no'
# Skipping le_meridien_riyadh because Mapped is not 'no'
# Skipping comfort_hotel_jeddah_king_road because Mapped is not 'no'
# Skipping novotel_suites_riyadh_dyar_2 because Mapped is not 'no'
# Skipping movenpick_hotel_tahlia_jeddah because Mapped is not 'no'
# Skipping the_hotel_galleria_by_elaf because Mapped is not 'no'
# Skipping residence_inn_by_marriott_dammam because Mapped is not 'no'
# Skipping staybridge_suites_al_khobar because Mapped is not 'no'
# Skipping marriott_riyadh_diplomatic_quarter because Mapped is not 'no'
# Skipping tulip_inn_riyadh because Mapped is not 'no'
# Skipping four_points_by_sheraton_riyadh_khaldia because Mapped is not 'no'
# Skipping voyage_hotel_5 because Mapped is not 'no'
# Skipping mira_business_hotel because Mapped is not 'no'
# Skipping grand_plaza_hotelking_fahad_riyadh because Mapped is not 'no'
# Skipping four_seasons_hotel_riyadh because Mapped is not 'no'
# Skipping copthorne_makkah_al_naseem because Mapped is not 'no'
# Skipping crowne_plaza_madinah because Mapped is not 'no'
# Skipping jareed_riyadh because Mapped is not 'no'
# Skipping cantonal_hotel_by_warwick because Mapped is not 'no'
# Skipping cloud7_residence_alula because Mapped is not 'no'
# Skipping sidrathul_aaliya_hotel because Mapped is not 'no'
# Skipping millennium_madinah_airport because Mapped is not 'no'
# Skipping holiday_inn_riyadh_al_qasr because Mapped is not 'no'
# Skipping golden_ship_hotel_2 because Mapped is not 'no'
# Skipping novotel_jeddah_tahlia because Mapped is not 'no'
# Skipping crowne_plaza_hotel_al_khobar because Mapped is not 'no'
# Skipping almuhaidb_residence_abha because Mapped is not 'no'
# Skipping dar_al_tawheed_intercontinental_ because Mapped is not 'no'
# Skipping courtyard_jazan_by_marriott because Mapped is not 'no'
# Skipping habitas_alula because Mapped is not 'no'
# Skipping radisson_blu_hotel_riyadh_qurtuba because Mapped is not 'no'
# Skipping radisson_riyadh_airport because Mapped is not 'no'
# Skipping best_western_plus_buraidah because Mapped is not 'no'
# Skipping salsabil_by_warwick because Mapped is not 'no'
# Skipping ewaa_express because Mapped is not 'no'
# Skipping elaf_al_taqwa_hotel because Mapped is not 'no'
# Skipping prime_hotel_al_hamra_jeddah because Mapped is not 'no'
# Skipping y_platinum because Mapped is not 'no'
# Skipping views_hotel_residences because Mapped is not 'no'
# Skipping ewaa_express_hotel_buraydah because Mapped is not 'no'
# Skipping makarim_umm_alqura_hotel because Mapped is not 'no'
# Skipping hilton_riyadh_hotel_residences because Mapped is not 'no'
# Skipping zaha_al_munawara_hotel because Mapped is not 'no'
# Skipping citadines_abha because Mapped is not 'no'
# Skipping crowne_plaza_riyadh_minhal because Mapped is not 'no'
# Skipping ramada_continental_jeddah because Mapped is not 'no'
# Skipping innyar_hotel because Mapped is not 'no'
# Skipping swissotel_living_jeddah because Mapped is not 'no'
# Skipping al_shohada_hotel because Mapped is not 'no'
# Skipping coral_al_madinah_hotel because Mapped is not 'no'
# Skipping al_mashreq_boutique_hotel because Mapped is not 'no'
# Skipping mansard_riyadh_a_radisson_collection_hotel_2 because Mapped is not 'no'
# Skipping park_inn_by_radisson_al_khobar because Mapped is not 'no'
# Skipping intercontinental_taif because Mapped is not 'no'
# Skipping mora_hotel_3 because Mapped is not 'no'
# Skipping emaar_elite_hotel because Mapped is not 'no'
# Skipping jeddah_grand_beach_hotel because Mapped is not 'no'
# Skipping mirnian because Mapped is not 'no'
# Skipping crown_rose_hotel because Mapped is not 'no'
# Skipping artal_taiba_hotel because Mapped is not 'no'
# Skipping holiday_jazan_hotel because Mapped is not 'no'
# Skipping novotel_riyadh_sahafa_opening_march_2024 because Mapped is not 'no'
# Skipping park_inn_by_radisson_jeddah_madinah_road because Mapped is not 'no'
# Skipping crowne_plaza_jeddah_al_salam because Mapped is not 'no'
# Skipping coral_suliemaniah_2 because Mapped is not 'no'
# Skipping velvet_hotel_4 because Mapped is not 'no'
# Skipping grand_millennium_tabuk because Mapped is not 'no'
# Skipping grand_plaza_hoteljazan because Mapped is not 'no'
# Skipping park_inn_by_radisson_dammam because Mapped is not 'no'
# Skipping al_faisaliah_hotel_a_rosewood_hotel because Mapped is not 'no'
# Skipping al_eiman_royal_hotel because Mapped is not 'no'
# Skipping emaar_andalusia because Mapped is not 'no'
# Skipping boudl_al_sahafa because Mapped is not 'no'
# Skipping grand_plaza_dhabab_hotel because Mapped is not 'no'
# Skipping holiday_inn_tabuk because Mapped is not 'no'
# Skipping jasmine_garden_hotel because Mapped is not 'no'
# Skipping millennia_olaya_hotel_ because Mapped is not 'no'
# Skipping myrtle_2 because Mapped is not 'no'
# Skipping aber_khamis_mushait because Mapped is not 'no'
# Skipping coral_dhahran_hotel because Mapped is not 'no'
# Skipping super_8_al_riyadh_2 because Mapped is not 'no'
# Skipping banyan_tree_alula because Mapped is not 'no'
# Skipping holiday_inn_resort_half_moon_bay because Mapped is not 'no'
# Skipping elaf_al_mashaer_hotel because Mapped is not 'no'
# Skipping aber_altakhassusi_105 because Mapped is not 'no'
# Skipping tulip_inn_al_reef because Mapped is not 'no'
# Skipping sofitel_al_khobar_the_corniche because Mapped is not 'no'
# Skipping palms_lily_hotel_suites because Mapped is not 'no'
# Skipping intour_qurtoba because Mapped is not 'no'
# Skipping alhyatt_jeddah_continental_hotel because Mapped is not 'no'
# Skipping charli_hotel_jeddah because Mapped is not 'no'
# Skipping fairmont_ramla_riyadh_opening_soon because Mapped is not 'no'
# Skipping karem_riyadh_residence_hotel_apartment because Mapped is not 'no'
# Skipping _0x25d12 because Mapped is not 'no'
# Skipping warwick_riyadh_hotel because Mapped is not 'no'
# Skipping millennium_hail_hotel because Mapped is not 'no'
# Skipping habitat_hotel_al_khobar because Mapped is not 'no'
# Skipping _0x37d78 because Mapped is not 'no'
# Skipping casablanca_grand_hotel because Mapped is not 'no'
# Skipping ewaa_express_hotelal_olaya because Mapped is not 'no'
# Skipping waqf_outhman_bin_affan_hotel because Mapped is not 'no'
# Skipping marriott_executive_apartments_riyadh_makarim because Mapped is not 'no'
# Skipping cloud_7_residence_alula because Mapped is not 'no'
# Skipping al_ahsa_intercontinental because Mapped is not 'no'
# Skipping boudl_taif because Mapped is not 'no'
# Skipping gulanar_hotel because Mapped is not 'no'
# Processed narcissus_the_royal_hotel successfully with giata id: 1428454
# Skipping mena_hotel_tabuk because Mapped is not 'no'
# Skipping voco_al_khobar because Mapped is not 'no'
# Skipping boudl_buraydah because Mapped is not 'no'
# Skipping sas_hotel because Mapped is not 'no'
# Skipping holiday_inn_suites_al_khobar_an_ihg_hotel because Mapped is not 'no'
# Skipping orchid_hotel_9 because Mapped is not 'no'
# Skipping holiday_inn_jeddah_gateway because Mapped is not 'no'
# Skipping best_western_plus_riyadh because Mapped is not 'no'
# Skipping rabigh_park_hotel because Mapped is not 'no'
# Skipping fraser_suites_riyadh because Mapped is not 'no'
# Skipping luxury_night_hotel because Mapped is not 'no'
# Skipping beautat_hotel because Mapped is not 'no'
# Skipping retaj_al_rayyan_makkah because Mapped is not 'no'
# Skipping rosewood_corniche_4 because Mapped is not 'no'
# Skipping al_haram_hotel_by_al_rawda because Mapped is not 'no'
# Skipping boudl_wadi_aldawasir because Mapped is not 'no'
# Skipping boudl_alworoud because Mapped is not 'no'
# Skipping al_faisaliah_resort_spa because Mapped is not 'no'
# Skipping park_inn_by_radisson_jeddah_madinah_road_2 because Mapped is not 'no'
# Skipping anan_hotel_2 because Mapped is not 'no'
# Skipping intercontinental_al_jubail because Mapped is not 'no'
# Skipping seven_gardens_hotel_2 because Mapped is not 'no'
# Skipping novotel_dammam_business_park because Mapped is not 'no'
# Skipping swiss_spirit_metropolitan because Mapped is not 'no'
# Skipping intercityhotel_riyadh_malaz because Mapped is not 'no'
# Skipping al_muteb_suites_al_falah_1 because Mapped is not 'no'
# Skipping address_al_hamra because Mapped is not 'no'
# Skipping armada_hotel_jazan because Mapped is not 'no'
# Skipping the_house_hotel_jeddah_city_yard because Mapped is not 'no'
# Skipping al_aqeeq_hotel__by_al_rawda because Mapped is not 'no'
# Skipping enala_tabuk because Mapped is not 'no'
# Skipping oyo_582_al_tamayoz_al_raqi_al_salamah because Mapped is not 'no'
# Skipping makarim_mina_hotel because Mapped is not 'no'
# Skipping al_muhaidb_residence_al_ahsa because Mapped is not 'no'
# Skipping holiday_inn_jeddah_corniche because Mapped is not 'no'
# Skipping ascott_rafal_olaya_riyadh_4 because Mapped is not 'no'
# Skipping movenpick_hotel_al_khobar because Mapped is not 'no'
# Skipping the_st_regis_riyadh_2 because Mapped is not 'no'
# Skipping qasr_alshamal_hotel because Mapped is not 'no'
# Skipping le_meridien_jeddah because Mapped is not 'no'
# Skipping abha_palace because Mapped is not 'no'
# Skipping jazalah because Mapped is not 'no'
# Skipping al_rayah_hotel because Mapped is not 'no'
# Skipping badr_hotel because Mapped is not 'no'
# Skipping ibis_yanbu_ because Mapped is not 'no'
# Skipping almuhaidb_sudair because Mapped is not 'no'
# Skipping hilton_riyadh_olaya because Mapped is not 'no'
# Skipping al_hamra_palace_hotel_riyadh_3 because Mapped is not 'no'
# Skipping golden_dune_hotel because Mapped is not 'no'
# Skipping emaar_al_khlil because Mapped is not 'no'
# Skipping hafawah_suites because Mapped is not 'no'
# Skipping holiday_khaleej because Mapped is not 'no'
# Skipping new_madinah_hotel because Mapped is not 'no'
# Skipping niyaf_hotel_suites_2 because Mapped is not 'no'
# Skipping swiss_international_al_hamra_dammam because Mapped is not 'no'
# Skipping msharef_al_moden_suites because Mapped is not 'no'
# Skipping zaha_taiba_hotel because Mapped is not 'no'
# Skipping comfort_hotel_riyadh_olaya because Mapped is not 'no'
# Skipping marriott_executive_apartments_madinah because Mapped is not 'no'
# Skipping erfad_hotel because Mapped is not 'no'
# Skipping boudl_quraish because Mapped is not 'no'
# Skipping renz_hotel because Mapped is not 'no'
# Skipping rosalina_hotel because Mapped is not 'no'
# Skipping concorde_dar_al_khair_hotel because Mapped is not 'no'
# Skipping aber_unayzah because Mapped is not 'no'
# Skipping holiday_inn_suites_jubail_taibah because Mapped is not 'no'
# Skipping boudl_mahayel_aseer because Mapped is not 'no'
# Skipping hilton_garden_inn_tabuk because Mapped is not 'no'
# Skipping radisson_blu_yanbu because Mapped is not 'no'
# Skipping hilton_garden_inn_al_jubail because Mapped is not 'no'
# Skipping golden_new_al_safa because Mapped is not 'no'
# Skipping intercontinental_al_khobar because Mapped is not 'no'
# Skipping granada_palace_inn because Mapped is not 'no'
# Skipping central_park_hotel_bisha_fndq_sntrl_brk_bysh because Mapped is not 'no'
# Skipping aerotel_jeddah_transit_hotel_in_terminal_1 because Mapped is not 'no'
# Skipping al_murjan_crom_hotel because Mapped is not 'no'
# Skipping iris_boutique_narjis because Mapped is not 'no'
# Skipping braira_al_wezarat because Mapped is not 'no'
# Skipping al_farhan_suites_jeddah_ because Mapped is not 'no'
# Skipping executives_hotel_al_azizia because Mapped is not 'no'
# Skipping radisson_blu_hotel_residence_riyadh_diplomatic_quarters because Mapped is not 'no'
# Skipping park_inn_by_radisson_makkah_aziziyah_2 because Mapped is not 'no'
# Skipping boudl_al_sulimanyah because Mapped is not 'no'
# Skipping taba_alsalam_hotel because Mapped is not 'no'
# Skipping al_eairy_furnished_apts_al_madinah_14 because Mapped is not 'no'
# Skipping al_eairy_furnished_apt_al_madinah_1 because Mapped is not 'no'
# Skipping grand_zowar_hotel because Mapped is not 'no'
# Skipping ozone_hotel_3 because Mapped is not 'no'
# Skipping grand_makkah_hotel because Mapped is not 'no'
# Skipping oberoi_2 because Mapped is not 'no'
# Skipping mandarin_hotel_apartments because Mapped is not 'no'
# Skipping movenpick_hotel_qassim because Mapped is not 'no'
# Skipping gloria_inn because Mapped is not 'no'
# Skipping citadines_al_salamah_jeddah_2 because Mapped is not 'no'
# Skipping boudl_gardenia_resort because Mapped is not 'no'
# Skipping w_platinum_2 because Mapped is not 'no'
# Skipping tulip_inn_yanbu_2 because Mapped is not 'no'
# Skipping the_proud_hotel_2 because Mapped is not 'no'
# Skipping leader_al_muna_kareem_hotel_2 because Mapped is not 'no'
# Skipping hayat_heraa_suites because Mapped is not 'no'
# Skipping myan_al_urubah_hotel because Mapped is not 'no'
# Skipping zaha_hotel because Mapped is not 'no'
# Skipping shangrila_jeddah because Mapped is not 'no'
# Skipping holiday_inn_riyadholaya because Mapped is not 'no'
# Skipping blue_inn_2 because Mapped is not 'no'
# Skipping askant_al_hafayer because Mapped is not 'no'
# Skipping al_azhar_hotel_jeddah because Mapped is not 'no'
# Skipping awaliv_international_hotel because Mapped is not 'no'
# Skipping emerald_hotel_17 because Mapped is not 'no'
# Skipping aram_hotel_almeshael_exit_18 because Mapped is not 'no'
# Skipping ramada_hotel_and_suites_dammam because Mapped is not 'no'
# Skipping boudl_alfayhaa_2 because Mapped is not 'no'
# Skipping ewaa_express_hotelal_shati because Mapped is not 'no'
# Skipping grand_al_massa_hotel because Mapped is not 'no'
# Skipping jazan_inn because Mapped is not 'no'
# Skipping staybridge_suites_al_khobar_city_an_ihg_hotel because Mapped is not 'no'
# Skipping golden_andalus_hotel_abha because Mapped is not 'no'
# Skipping al_eiman_taibah because Mapped is not 'no'
# Skipping al_borg_al_watheer because Mapped is not 'no'
# Skipping emaar_mektan because Mapped is not 'no'
# Skipping cloud_city_hotel because Mapped is not 'no'
# Skipping radisson_blu_residence_dhahran because Mapped is not 'no'
# Skipping al_andlus_palace_2_hotel_kurban_fndq_qsr_lndls_2_qrbn because Mapped is not 'no'
# Skipping almuhaidb_residence_aldawadmi because Mapped is not 'no'
# Skipping motiara_hotel_la_valle_mall because Mapped is not 'no'
# Skipping _0x3d4f5 because Mapped is not 'no'
# Skipping ewaa_express_hotel_khorais because Mapped is not 'no'
# Skipping nivel_hotel because Mapped is not 'no'
# Skipping enala_hotel_umluj because Mapped is not 'no'
# Skipping park_hyatt_jeddah__marina_club_and_spa because Mapped is not 'no'
# Skipping boudl_palestine because Mapped is not 'no'
# Skipping aber_103_al_mounisya because Mapped is not 'no'
# Skipping the_westin_jeddah because Mapped is not 'no'
# Skipping dar_al_eiman_grand because Mapped is not 'no'
# Skipping boudl_al_munsiyah because Mapped is not 'no'
# Skipping ewaa_express_hotel_gaber because Mapped is not 'no'
# Skipping iris_boutique_taif_heart because Mapped is not 'no'
# Skipping platinum_boutique_al_naeem because Mapped is not 'no'
# Skipping al_saha_hotel because Mapped is not 'no'
# Skipping flavor because Mapped is not 'no'
# Skipping iridium_70_hotel because Mapped is not 'no'
# Skipping ramada_al_qassim_hotel_and_suites because Mapped is not 'no'
# Skipping qasr_al_sahab because Mapped is not 'no'
# Skipping al_massa_hotel because Mapped is not 'no'
# Skipping royal_casablanca because Mapped is not 'no'
# Skipping midan_hotel_ because Mapped is not 'no'
# Skipping millennium_al_aqeeq_hotel because Mapped is not 'no'
# Skipping sarwat_park_hotel_riyadhdiplomatic_quarter_fndq_srwt_brk_lrydhy_lsfrt because Mapped is not 'no'
# Skipping copthorne_hotel_riyadh because Mapped is not 'no'
# Skipping habitat_hotel because Mapped is not 'no'
# Skipping holiday_inn_al_khobar_3 because Mapped is not 'no'
# Skipping novotel_al_anoud because Mapped is not 'no'
# Skipping radisson_blu_resort_al_khobar_half_moon_bay because Mapped is not 'no'
# Skipping riyadh_diplomatic_quarter_marriott_executive_apartments because Mapped is not 'no'
# Skipping dara_alrayyan_hotel because Mapped is not 'no'
# Skipping kyona_alaziziyah because Mapped is not 'no'
# Skipping boudl_majmaa_apartment_2 because Mapped is not 'no'
# Skipping season_star_hotel because Mapped is not 'no'
# Skipping accor_palace_riyadh because Mapped is not 'no'
# Skipping park_inn_by_radisson_hotel_apartments_dammam_industrial_city because Mapped is not 'no'
# Skipping park_inn_by_radisson_makkah_aziziyah because Mapped is not 'no'
# Skipping park_inn_by_radisson_jubail_industrial_city because Mapped is not 'no'
# Skipping kyona_purpel because Mapped is not 'no'
# Skipping diamond_suites_8 because Mapped is not 'no'
# Skipping wa_hotel_3 because Mapped is not 'no'
# Skipping prime_al_corniche_hotel because Mapped is not 'no'
# Skipping grand_plaza_al_madina_ex_al_salhiya_tibah because Mapped is not 'no'
# Skipping hdb_resort_spa_alkhobar because Mapped is not 'no'
# Skipping golden_gewan_hotel_abha because Mapped is not 'no'
# Skipping mercure_makkah_aziziah because Mapped is not 'no'
# Processed saja_hotels_makkah successfully with giata id: 1433106
# Skipping ascott_corniche_al_khobar because Mapped is not 'no'
# Skipping centro_corniche_al_khobar because Mapped is not 'no'
# Skipping naviti_warwick_dammam_2 because Mapped is not 'no'
# Skipping al_ansar_golden_tulip because Mapped is not 'no'
# Skipping diwan_residence_hotel_alnaeem because Mapped is not 'no'
# Skipping makeen_homes_by_warwick because Mapped is not 'no'
# Skipping le_park_concord_rabwah_riyadh because Mapped is not 'no'
# Skipping raytna_al_wadi because Mapped is not 'no'
# Skipping qasr_lazurd because Mapped is not 'no'
# Skipping grand_plaza_badr_al_maqam_ma because Mapped is not 'no'
# Skipping golden_bujari_hotel_bisha because Mapped is not 'no'
# Skipping boudl_almaidan because Mapped is not 'no'
# Skipping elite_of_elite because Mapped is not 'no'
# Skipping oyo_273_star_yanbu_hotel_suites because Mapped is not 'no'
# Skipping areen_airport_hotel because Mapped is not 'no'
# Skipping the_jeddah_edition because Mapped is not 'no'
# Skipping emaar_al_dewan_al_sud because Mapped is not 'no'
# Skipping duset_hotel_suites because Mapped is not 'no'
# Skipping hayat_alriyadh_hotel because Mapped is not 'no'
# Skipping boudl_al_wadi_hotel because Mapped is not 'no'
# Skipping swiss_in_park_tabuk because Mapped is not 'no'
# Skipping ewaa_express_hotel_al_jouf because Mapped is not 'no'
# Skipping khabti_grand_hotel because Mapped is not 'no'
# Skipping artal_international_hotel because Mapped is not 'no'
# Skipping al_mokhtara_diamond because Mapped is not 'no'
# Skipping holiday_inn_al_khobar_corniche because Mapped is not 'no'
# Skipping golden_tulip_riyadh because Mapped is not 'no'
# Skipping radisson_blu_resort_jizan because Mapped is not 'no'
# Skipping boudl_al_qasr because Mapped is not 'no'
# Skipping burj_al_hayat_furnished_suites because Mapped is not 'no'
# Skipping comfort_inn_163 because Mapped is not 'no'
# Skipping dana_rayhaan_by_rotana because Mapped is not 'no'
# Skipping ramada_by_wyndham_al_khobar_king_abdullah_street because Mapped is not 'no'
# Skipping rio_hotel_olaya because Mapped is not 'no'
# Skipping paradise_inn_jeddah because Mapped is not 'no'
# Skipping holiday_inn_najran because Mapped is not 'no'
# Skipping waad_al_ula_hotel because Mapped is not 'no'
# Skipping emaar_al_manar because Mapped is not 'no'
# Processed ross_hotel successfully with giata id: 1427254
# Skipping al_farhan_hotel_suites_al_aqiq_ because Mapped is not 'no'
# Skipping ascott_sari_jeddah_2 because Mapped is not 'no'
# Skipping alreem_hotel because Mapped is not 'no'
# Skipping almuhaidb_residence because Mapped is not 'no'
# Skipping almuhaidb_furnished_units_king_abdulaziz because Mapped is not 'no'
# Skipping centro_corniche_al_khobar_by_rotana because Mapped is not 'no'
# Skipping shada_hotel_shati because Mapped is not 'no'
# Skipping al_muteb_suites_al_najah because Mapped is not 'no'
# Skipping hampton_by_hilton_sharma because Mapped is not 'no'
# Skipping hyatt_place_riyadh_al_sulaimania because Mapped is not 'no'
# Skipping al_eairy_furnished_apartments_jizan_1 because Mapped is not 'no'
# Skipping somewhere_bliss because Mapped is not 'no'
# Skipping aquila_hotel because Mapped is not 'no'
# Skipping al_muteb_suites_al_ezdehar_2 because Mapped is not 'no'
# Skipping al_safwah_royale_orchid because Mapped is not 'no'
# Skipping aber_102 because Mapped is not 'no'
# Skipping aber_abha because Mapped is not 'no'
# Skipping basma_plaza because Mapped is not 'no'
# Skipping boudl_al_tahlia because Mapped is not 'no'
# Skipping grand_park_hotel_7 because Mapped is not 'no'
# Skipping awaliv_suites because Mapped is not 'no'
# Skipping aber_101 because Mapped is not 'no'
# Skipping faraj_al_madina_hotel because Mapped is not 'no'
# Skipping al_rayyan_towers_hotel_mecca1 because Mapped is not 'no'
# Skipping hamsa_fajr_furnished_apartments because Mapped is not 'no'
# Skipping park_inn_by_radisson_makkah_thakher_east because Mapped is not 'no'
# Skipping dar_al_wedad_hotel because Mapped is not 'no'
# Skipping city_view_hotel_by_crown_town because Mapped is not 'no'
# Skipping golden_tulip_abha because Mapped is not 'no'
# Skipping skyline_hotel_suites_3 because Mapped is not 'no'
# Skipping radisson_hotel_residence_riyadh_olaya because Mapped is not 'no'
# Skipping al_muteb_suites_al_yarmouk_2 because Mapped is not 'no'
# Skipping emaar_grand_hotel because Mapped is not 'no'
# Skipping golden_alareen because Mapped is not 'no'
# Skipping holiday_inn_meydan because Mapped is not 'no'
# Skipping refaaf_al_azizia_hotel because Mapped is not 'no'
# Skipping alwateen_hotel because Mapped is not 'no'
# Skipping sweet_land_hotel because Mapped is not 'no'
# Skipping golden_tulip_al_zahabi because Mapped is not 'no'
# Skipping narcissus_resort_spa_obhur_jeddah because Mapped is not 'no'
# Skipping triple_tree because Mapped is not 'no'
# Skipping al_eairy_furnished_apt_al_madinah_3 because Mapped is not 'no'
# Skipping almaali_hotel because Mapped is not 'no'
# Skipping merfal_hotel_apartment_royal because Mapped is not 'no'
# Skipping tulip_plaza_hafr_al_batin because Mapped is not 'no'
# Skipping wajiht_najran because Mapped is not 'no'
# Skipping rest_night_hotel_apartment__al_hamra because Mapped is not 'no'
# Skipping almuhaidb_al_olaya_3 because Mapped is not 'no'
# Skipping almuhaidb_residence_al_jubail because Mapped is not 'no'
# Skipping rest_night_hotel_suites_al_nafal because Mapped is not 'no'
# Skipping tulip_inn_al_dar_rawafed because Mapped is not 'no'
# Skipping boudl_alfayhaa_7 because Mapped is not 'no'
# Skipping al_farhan_hotel_suites_exit_15 because Mapped is not 'no'
# Skipping makkah_hotel because Mapped is not 'no'
# Skipping hyatt_buyutat_apartment because Mapped is not 'no'
# Skipping naviti_warwick_dammam because Mapped is not 'no'
# Skipping rafa_al_nuzhah because Mapped is not 'no'
# Skipping donatello_hotel_2 because Mapped is not 'no'
# Skipping doubletree_by_hilton_riyadh_financial_district_hotelsuites because Mapped is not 'no'
# Skipping oyo_589_lavina_house because Mapped is not 'no'
# Skipping al_majeedi_arac_suites_ because Mapped is not 'no'
# Skipping movenpick_hotel_city_star_jeddah because Mapped is not 'no'
# Skipping lafontaine_opal_hotel because Mapped is not 'no'
# Skipping shaden_resort_al_ulla because Mapped is not 'no'
# Skipping nusk_al_hijrah_hotel because Mapped is not 'no'
# Skipping brzeen because Mapped is not 'no'
# Skipping boudl_rass_ because Mapped is not 'no'
# Skipping iridium_hotel_taif because Mapped is not 'no'
# Skipping golden_new_quraish_jeddah because Mapped is not 'no'
# Skipping hamsa_hotel_apartment because Mapped is not 'no'
# Skipping makkah_hotel_and_towers because Mapped is not 'no'
# Skipping swiss_spirit_hotel_suites_dammam_corniche because Mapped is not 'no'
# Skipping al_tawfiq_plaza_hotel because Mapped is not 'no'
# Skipping taiba_arac_suites because Mapped is not 'no'
# Skipping zara_continental_hotel because Mapped is not 'no'
# Skipping garden_plaza_hotel_7 because Mapped is not 'no'
# Skipping karam_taibah_almasi because Mapped is not 'no'
# Skipping le_park_concord_arar because Mapped is not 'no'
# Skipping al_muteb_suites_al_falah_3 because Mapped is not 'no'
# Skipping holiday_inn_yanbu_5 because Mapped is not 'no'
# Skipping sama_al_madinah_hotel because Mapped is not 'no'
# Skipping park_jizan_hotel because Mapped is not 'no'
# Skipping al_muhaidb_alghzali_hotel because Mapped is not 'no'
# Skipping mokhtara_international because Mapped is not 'no'
# Skipping swiss_blue_al_samer because Mapped is not 'no'
# Skipping sheraton_dammam_hotel_towers_3 because Mapped is not 'no'
# Skipping voyage_residence because Mapped is not 'no'
# Skipping malfa_hotel_apartments because Mapped is not 'no'
# Skipping al_shahba_hotel_makkah because Mapped is not 'no'
# Skipping al_buhaira_hotel because Mapped is not 'no'
# Skipping dar_al_naeem_hotel because Mapped is not 'no'
# Skipping le_park_concord_turayf because Mapped is not 'no'
# Skipping aber_106_abha because Mapped is not 'no'
# Skipping ewaa_express_hotel_alrawda because Mapped is not 'no'
# Skipping hasana_suites because Mapped is not 'no'
# Skipping aber_al_yasmin because Mapped is not 'no'
# Skipping hyatt_house_jeddah_sari_street because Mapped is not 'no'
# Skipping karam_jeddah_hotel because Mapped is not 'no'
# Skipping rose_park because Mapped is not 'no'
# Skipping yar_furnished_apartments because Mapped is not 'no'
# Skipping swiss_in_tabuk_hotel because Mapped is not 'no'
# Skipping kease_hittin_b_5_elegance_ag32 because Mapped is not 'no'
# Skipping kease_malqa_b3_royal_touch_ag28 because Mapped is not 'no'
# Processed le_park_concord_rabwah_boutique_hotel_2 successfully with giata id: 1316096
# Skipping burj_alhayah_hotel_suites_alfalah because Mapped is not 'no'
# Skipping boudl_al_fakhria because Mapped is not 'no'
# Skipping boudl_al_shatea because Mapped is not 'no'
# Skipping almuhaidb_faisaliah_hotel_suites because Mapped is not 'no'
# Skipping royal_dar_al_eiman because Mapped is not 'no'
# Skipping al_eairy_furnished_apartments_dammam_3 because Mapped is not 'no'
# Skipping golden_bujari_aldhahran_hotel because Mapped is not 'no'
# Skipping comfort_inn_al_yarmouk_2 because Mapped is not 'no'
# Skipping al_diafah_apartments_olaya_3 because Mapped is not 'no'
# Skipping boudl_khamis_mushait because Mapped is not 'no'
# Skipping crowne_plaza_55 because Mapped is not 'no'
# Skipping rona_hotel_2 because Mapped is not 'no'
# Skipping al_tayseer_towers_hotel because Mapped is not 'no'
# Skipping jeddah_trident_hotel because Mapped is not 'no'
# Skipping golden_tulip_buraidah_al_qassim because Mapped is not 'no'
# Skipping coral_olaya_hotel_riyadh because Mapped is not 'no'
# Skipping mirage_al_salam_hotel because Mapped is not 'no'
# Skipping grand_day because Mapped is not 'no'
# Skipping al_diyafa_hotel because Mapped is not 'no'
# Skipping four_seasons_hotel_apartment_2 because Mapped is not 'no'
# Skipping karan_hotel because Mapped is not 'no'
# Skipping almuhaidb_residence_hotel_al_khafji because Mapped is not 'no'
# Skipping motiara_hotel because Mapped is not 'no'
# Skipping lamar_ajyad_hotel_2_tower_b because Mapped is not 'no'
# Skipping eva_hotel_10 because Mapped is not 'no'
# Skipping time_dammam_residence because Mapped is not 'no'
# Skipping oyo_586_al_tamayoz_al_raqi_hira because Mapped is not 'no'
# Skipping rihanna_inn_hotel_apartement because Mapped is not 'no'
# Skipping hotel_karam_al_madina because Mapped is not 'no'
# Processed nova_m_hotel_edge_by_rotana successfully with giata id: 1432054
# Processed dar_tantora_the_house_hotel successfully with giata id: 1445377
# Skipping raoum_inn_khafji_southern_ because Mapped is not 'no'
# Skipping boudl_almalaz because Mapped is not 'no'
# Skipping city_center_plaza_aparthotel because Mapped is not 'no'
# Skipping rove_jeddah_hotel because Mapped is not 'no'
# Skipping al_eairy_furnished_apartments_al_baha_2 because Mapped is not 'no'
# Skipping v_boutique_hotel_5 because Mapped is not 'no'
# Skipping al_safwah_hotel_tower_1 because Mapped is not 'no'
# Skipping platinum_suites__2 because Mapped is not 'no'
# Skipping raoum_inn_buraydah because Mapped is not 'no'
# Skipping al_noor_hotel_makkah because Mapped is not 'no'
# Skipping raoum_inn_hafr_al_baten because Mapped is not 'no'
# Skipping al_alya_hotel_rooms_and_suites because Mapped is not 'no'
# Skipping makarim_albait_hotel because Mapped is not 'no'
# Skipping viola_gardens because Mapped is not 'no'
# Skipping iwan_alandalusia_hotel_suites_alrehab_2 because Mapped is not 'no'
# Skipping courtyard_by_marriott_jubail because Mapped is not 'no'
# Skipping al_hidayah_towers because Mapped is not 'no'
# Skipping mercure_al_khobar_hotel because Mapped is not 'no'
# Skipping al_muhaidb_for_hotel_apartments_24 because Mapped is not 'no'
# Skipping gardenia_inn_hotel_suites because Mapped is not 'no'
# Skipping radisson_blu_hotel_buraidah because Mapped is not 'no'
# Skipping almuhaidib_jubail because Mapped is not 'no'
# Skipping signature_hotel_5 because Mapped is not 'no'
# Skipping three_points_musalli_makkah_hotel because Mapped is not 'no'
# Skipping golden_prince_al_sulaymaniyah_hotel because Mapped is not 'no'
# Skipping aknan_serviced_apartments_1 because Mapped is not 'no'
# Skipping ramada_by_wyndham_makkah_zad_al_rawda because Mapped is not 'no'
# Skipping nusk_al_madinah_hotel because Mapped is not 'no'
# Skipping sama_al_qasr_hotel_apartment_elmohamadia because Mapped is not 'no'
# Skipping sela_hotel because Mapped is not 'no'
# Skipping boudl_al_jubail because Mapped is not 'no'
# Processed damac_towers_olaya_by_selsal successfully with giata id: no
# Skipping grand_lily_hotel_suites_ because Mapped is not 'no'
# Skipping swiss_international_park_hotel because Mapped is not 'no'
# Skipping taleen_alaqiq_hotel_apartments because Mapped is not 'no'
# Skipping boudl_al_masif_2 because Mapped is not 'no'
# Skipping taleen_al_sahafa_ because Mapped is not 'no'
# Skipping boudl_tahaliah because Mapped is not 'no'
# Skipping rayatna_for_furnished_apartments_2 because Mapped is not 'no'
# Skipping rest_night_hotel_apartments because Mapped is not 'no'
# Skipping admire_apart_hotel_2 because Mapped is not 'no'
# Skipping saraya_building2 because Mapped is not 'no'
# Skipping ekono_by_leva_jeddah_airport_hotel because Mapped is not 'no'
# Skipping dana_hotel_residences_qassim because Mapped is not 'no'
# Skipping alandalus_mall_hotel because Mapped is not 'no'
# Skipping aris_star because Mapped is not 'no'
# Skipping bram_hotel_suites because Mapped is not 'no'
# Skipping al_eairy_furnished_apts_al_madinah_13 because Mapped is not 'no'
# Skipping wow_jeddah_hotel because Mapped is not 'no'
# Skipping naviti_warwick_al_khobar because Mapped is not 'no'
# Skipping garden_plaza_hotel_sefah because Mapped is not 'no'
# Skipping aldaar_jizan because Mapped is not 'no'
# Skipping ruve_jeddah_hotel because Mapped is not 'no'
# Skipping triple_tree_hotel because Mapped is not 'no'
# Skipping al_farhan_hotel_suites_2 because Mapped is not 'no'
# Skipping boudl_al_olaya because Mapped is not 'no'
# Skipping nozl_alhejaz_1_apartshotel because Mapped is not 'no'
# Skipping noor_al_thuraya_ajyad because Mapped is not 'no'
# Skipping wirgan_hotel_al_azizyah_2 because Mapped is not 'no'
# Skipping golden_tulip_riyadh_2 because Mapped is not 'no'
# Skipping best_western_ajyad_makkah because Mapped is not 'no'
# Skipping rawasi_hotel_suites because Mapped is not 'no'
# Skipping boudl_gaber because Mapped is not 'no'
# Skipping infinity_hotel_makkah because Mapped is not 'no'
# Skipping almuhaidb_residence_almaadi because Mapped is not 'no'
# Skipping etlalet_ebhar_furnished_units because Mapped is not 'no'
# Skipping al_kiram_hotel because Mapped is not 'no'
# Skipping carawan_al_khaleej_hotel_riyadh because Mapped is not 'no'
# Skipping address_palace_hotel_apartments because Mapped is not 'no'
# Skipping rama_yanbu_hotelsuite because Mapped is not 'no'
# Skipping fndq_lfyr_n_lavera_inn_hotel because Mapped is not 'no'
# Skipping hilton_al_khobar_king_fahd_causeway because Mapped is not 'no'
# Skipping emaar_taiba_hotel because Mapped is not 'no'
# Skipping wings_of_albaida_alsalam_branch because Mapped is not 'no'
# Skipping royal_inn_al_rawda__dyar_international_previously because Mapped is not 'no'
# Skipping dorat_najd_resort because Mapped is not 'no'
# Skipping somerset_downtown_al_khobar because Mapped is not 'no'
# Skipping al_muteb_suites_khurais because Mapped is not 'no'
# Skipping rovotel_hotel because Mapped is not 'no'
# Skipping holiday_al_khaleej_hotel_2 because Mapped is not 'no'
# Skipping violet_al_azizia_hotel because Mapped is not 'no'
# Skipping salsbil_al_almasi_hotel because Mapped is not 'no'
# Skipping hawthorn_suites_by_wyndham_al_khobar because Mapped is not 'no'
# Skipping roshan_al_azhar_hotel because Mapped is not 'no'
# Skipping taleen_almasif_hotel_apartments because Mapped is not 'no'
# Skipping al_farhan_hotel_suites_al_fayha because Mapped is not 'no'
# Skipping intour_al_khafji_hotel because Mapped is not 'no'
# Skipping aber_al_takhasussi because Mapped is not 'no'
# Skipping swiss_spirit_hotel_suites_taif because Mapped is not 'no'
# Skipping la_rive_hotels_suites_ex_ghosn_al_banafsej_hotel_apartments because Mapped is not 'no'
# Skipping niara_hotel_apartments because Mapped is not 'no'
# Skipping al_mutlaq_hotel because Mapped is not 'no'
# Skipping coral_jubail_hotel_2 because Mapped is not 'no'
# Skipping al_muhaideb_resort_taif because Mapped is not 'no'
# Skipping royal_boutique_hotel_khamis_mushait because Mapped is not 'no'
# Processed courtyard_by_marriott_makkah successfully with giata id: 1432067
# Skipping sarwat_park_hotel because Mapped is not 'no'
# Skipping the_palace_hotel_suites_3 because Mapped is not 'no'
# Skipping dar_otel because Mapped is not 'no'
# Skipping al_jadel_hotel because Mapped is not 'no'
# Skipping holiday_plus because Mapped is not 'no'
# Skipping celine_home_serviced_apartments_tawiq because Mapped is not 'no'
# Skipping suite_inn_hotel_riyadh because Mapped is not 'no'
# Skipping raoum_inn_sakaka because Mapped is not 'no'
# Skipping golden_tulip_suites_al_khobar because Mapped is not 'no'
# Skipping kadi_hotel because Mapped is not 'no'
# Skipping al_safeer because Mapped is not 'no'
# Skipping mercure_hibatullah_hotel because Mapped is not 'no'
# Skipping _0x2ff30 because Mapped is not 'no'
# Skipping taleen_durrat_al_nakhil because Mapped is not 'no'
# Skipping lafontaine_hotel_jeddah because Mapped is not 'no'
# Skipping rest_night_hotel_apartment because Mapped is not 'no'
# Skipping nourth_house_aparthotel_2 because Mapped is not 'no'
# Skipping le_park_concord_hotel_sakaka because Mapped is not 'no'
# Skipping rose_plaza_jazan because Mapped is not 'no'
# Skipping time_ruba_hotel_and_suites because Mapped is not 'no'
# Skipping emaar_legend because Mapped is not 'no'
# Processed beat_salsbil_hotel successfully with giata id: 1433340
# Skipping dar_al_ghufran_hotel because Mapped is not 'no'
# Skipping alwaha_residential because Mapped is not 'no'
# Skipping revan_palace because Mapped is not 'no'
# Skipping happy_beach_group_al_basatin_ because Mapped is not 'no'
# Skipping canary_beach_hotel_ because Mapped is not 'no'
# Skipping shally_residence_3 because Mapped is not 'no'
# Skipping dar_al_bayan_hotel because Mapped is not 'no'
# Skipping golden_tulip_riyadh_4 because Mapped is not 'no'
# Skipping swiss_blue_hira because Mapped is not 'no'
# Skipping verta_madina_hotel because Mapped is not 'no'
# Skipping aram_hotel because Mapped is not 'no'
# Skipping arkan_al_manar because Mapped is not 'no'
# Processed sedra_mecca_hotel_2 successfully with giata id: 1433141
# Skipping taleen_al_naseem because Mapped is not 'no'
# Skipping alma_hotel_15 because Mapped is not 'no'
# Skipping damac_towers_arjaan_by_rotana_riyadh because Mapped is not 'no'
# Skipping towlan_hotel_suites_1 because Mapped is not 'no'
# Skipping jw_inn_hotel because Mapped is not 'no'
# Skipping concorde_mina_hotel because Mapped is not 'no'
# Skipping crown_town_hotel_suites because Mapped is not 'no'
# Skipping novotel_yanbu_albahr because Mapped is not 'no'
# Skipping olayan_suites because Mapped is not 'no'
# Skipping park_inn_by_radisson_najran because Mapped is not 'no'
# Skipping ibis_jeddah_malik_road_opening_april_2019 because Mapped is not 'no'
# Skipping al_eairy_furnished_apartments_dammam_8 because Mapped is not 'no'
# Skipping zahrat_rozah because Mapped is not 'no'
# Skipping areen_hotel_al_naeem because Mapped is not 'no'
# Skipping lailaty because Mapped is not 'no'
# Skipping shada_hotel_shatea because Mapped is not 'no'
# Skipping courtyard_jubail because Mapped is not 'no'
# Skipping comfort_inn_al_yarmouk_4 because Mapped is not 'no'
# Skipping badrani_b_qaswarah_residence because Mapped is not 'no'
# Skipping radwan_al_diyafah_hotel because Mapped is not 'no'
# Processed dana_hotel_6 successfully with giata id: 1294104
# Skipping towlan_qurtaba because Mapped is not 'no'
# Skipping aswar_hotel_suite_al_ulaya because Mapped is not 'no'
# Skipping park_inn_by_radisson_riyadh_3 because Mapped is not 'no'
# Skipping ramada_encore_wyndham_al_khobar_corniche because Mapped is not 'no'
# Skipping sunset_hotel_16 because Mapped is not 'no'
# Skipping golden_tulip_al_khobar because Mapped is not 'no'
# Skipping bayat_by_cristal_hotel because Mapped is not 'no'
# Skipping warwick_al_khobar because Mapped is not 'no'
# Skipping voyage_apartments_2 because Mapped is not 'no'
# Skipping rose_jeddah_hotel because Mapped is not 'no'
# Skipping nawazi_towers_hotel because Mapped is not 'no'
# Skipping aya_hostel_for_shared_bedrooms because Mapped is not 'no'
# Skipping karim_hotel_ras_tanura because Mapped is not 'no'
# Processed golden_new_umu_alquraa_hotel successfully with giata id: 1416815
# Processed holiday_suites_al_azizia successfully with giata id: no
# Processed al_safwah_hotel_tower_3 successfully with giata id: 1430632
# Skipping alsaraya_hotel_suites because Mapped is not 'no'
# Processed rose_sharurah_serviced_apartments successfully with giata id: no
# Skipping centro_waha_2 because Mapped is not 'no'
# Skipping khalifa_tower because Mapped is not 'no'
# Skipping mawaddah_nama_hotel because Mapped is not 'no'
# Skipping vivienda_hotel_villas_granada because Mapped is not 'no'
# Skipping royal_al_mashaer_hotel because Mapped is not 'no'
# Skipping beyab_al_hamra because Mapped is not 'no'
# Skipping taleen_al_nadwa because Mapped is not 'no'
# Skipping address_tower_hotel because Mapped is not 'no'
# Skipping delights_inn because Mapped is not 'no'
# Skipping three_points_al_salama because Mapped is not 'no'
# Skipping al_thuria_hotel because Mapped is not 'no'
# Skipping al_mawasem_al_arbaa because Mapped is not 'no'
# Skipping boudl_heraa because Mapped is not 'no'
# Skipping platinum_albiea because Mapped is not 'no'
# Skipping al_muhaidb_takhassusi_30 because Mapped is not 'no'
# Skipping blue_sands_triple_three because Mapped is not 'no'
# Skipping shada_suites_al_hamra_hotel because Mapped is not 'no'
# Skipping obhur_home_hotel_apartments because Mapped is not 'no'
# Skipping qamar_hotel_jeddah because Mapped is not 'no'
# Skipping al_janoub_hotel_by_oyo_rooms because Mapped is not 'no'
# Skipping areen_hotel_2 because Mapped is not 'no'
# Skipping al_muhaidb_residence because Mapped is not 'no'
# Skipping makkah_millennium_towers because Mapped is not 'no'
# Skipping batoul_ajyad because Mapped is not 'no'
# Skipping hotel_21_13 because Mapped is not 'no'
# Skipping sahari_alforsan_hotel because Mapped is not 'no'
# Skipping grand_valley_hotel_2 because Mapped is not 'no'
# Skipping carlton_al_moaibed_hotel_3 because Mapped is not 'no'
# Skipping tulip_inn_al_khobar because Mapped is not 'no'
# ...
# Skipping oyo_506_eskan_9_hotel_2 because Mapped is not 'no'
# Skipping safwt_aldyar_furnished_units because Mapped is not 'no'
# Skipping tuwaren_suites because Mapped is not 'no'
# Skipping safwat_al_sharia_hotel because Mapped is not 'no'
# Skipping holiday_furnished_units because Mapped is not 'no'
# Skipping hekayat_abeer_hotel_apartments because Mapped is not 'no'
# Skipping ezwa_house_hotel because Mapped is not 'no'
# Skipping diaar_hotel_appartments because Mapped is not 'no'
# Skipping alarab_mashaer_hotel because Mapped is not 'no'
# Skipping al_khalidiya_suite_hotel_apartments because Mapped is not 'no'
# Skipping al_hayat_inn_hotel_suites because Mapped is not 'no'
# Skipping oyo_576_shrooq_albaha_2 because Mapped is not 'no'
# Skipping sama_al_rifaa_3 because Mapped is not 'no'
# Skipping danat_alnakheel_chalet because Mapped is not 'no'
# Skipping onaizah_hotel_by_gulanar because Mapped is not 'no'
# Skipping al_qaser_furnished_units because Mapped is not 'no'
# Skipping layali_al_ulaya_furnished_unites_2 because Mapped is not 'no'
# Skipping dormera_aqiq because Mapped is not 'no'
# Skipping oyo_633_home_ibs_3_2bhk because Mapped is not 'no'
# Skipping nozol_ghayda because Mapped is not 'no'
# Skipping tabah_towers_hotel because Mapped is not 'no'
# Skipping sama_al_masi_hotel because Mapped is not 'no'
# Skipping nozl_alhejaz_4_apartshotel because Mapped is not 'no'
# Skipping rafahya_hotel because Mapped is not 'no'
# Skipping fribion_apathotel because Mapped is not 'no'
# Skipping forsan_ajyad_hotel because Mapped is not 'no'
# Skipping al_fayroz_al_qibla because Mapped is not 'no'
# Skipping fndq_knwz_lnsym_bwst_sm_str because Mapped is not 'no'
# Skipping swiss_by_pioneer because Mapped is not 'no'
# Skipping relax_day_hotel_appartments because Mapped is not 'no'
# Skipping fyl_dwr_rdy_fy_shml_brydh_4_grf_nwm_llwyl_lgyr_lmdkhnyn because Mapped is not 'no'
# Skipping rb_raeha_albustan because Mapped is not 'no'
# Skipping private_chalet_with_pool_shlyh_fkhm_m_msbh because Mapped is not 'no'
# Skipping mntj_lwd because Mapped is not 'no'
# Skipping alhasani_plaza_adham because Mapped is not 'no'
# Skipping aber_bani_amr because Mapped is not 'no'
# Skipping 1bedroom_apartment_with_underground_parking because Mapped is not 'no'
# Skipping grf_fndqy_rqy_studio_in_damac_by_fendi_riyadh because Mapped is not 'no'
# Skipping kease_qirwan_a12_royal_touch_gz55 because Mapped is not 'no'
# Skipping 1_the_luxury_home_brj_lshty_whd_llwyl_fqt because Mapped is not 'no'
# Skipping shqq_fkhm_lmryn_grandeur_marina_apartments because Mapped is not 'no'
# Skipping jnh_bys_baeza_suites because Mapped is not 'no'
# Skipping kease_arid_h_2_luxury_gold_balcony_ag35 because Mapped is not 'no'
# Skipping kease_malqa_a13_royal_touch_xz88 because Mapped is not 'no'
# Skipping shq_l_lbhr_fy_lbylsn_kaec_sea_view because Mapped is not 'no'
# Skipping nrfn_ryzdns_3_grf_nirvana_residence_3_bedrooms because Mapped is not 'no'
# Skipping cozy_private_apartment_16 because Mapped is not 'no'
# Skipping lrwqn_hwstlchillax_hostel because Mapped is not 'no'
# Skipping damac_al_jawharah_tower_apartments because Mapped is not 'no'
# Skipping mabaat_damac_tower_al_corniche_450 because Mapped is not 'no'
# Skipping the_f_residence_elegant_luxury because Mapped is not 'no'
# Skipping kease_mughrizat_c1_royal_touch_gz57 because Mapped is not 'no'
# Skipping kease_sahafa_c11_royal_touch_gx73 because Mapped is not 'no'
# Skipping kease_malqa_b1_royal_blackness_az18 because Mapped is not 'no'
# Skipping marina2_sea_view_wyl_fqt because Mapped is not 'no'
# Skipping reef101 because Mapped is not 'no'
# Skipping almakan_suites_111_3 because Mapped is not 'no'
# Skipping fl_lljnh_lfndqy_lnzh because Mapped is not 'no'
# Skipping al_raha_apartment_hotel_2 because Mapped is not 'no'
# Skipping al_sondos_furnished_apartments_2 because Mapped is not 'no'
# Skipping weekend_hotel_and_resort because Mapped is not 'no'
# Skipping brj_lsbhy because Mapped is not 'no'
# Skipping drr_rmh_lljnh_lfndqy_2 because Mapped is not 'no'
# Skipping shq_hdy_bmwq_mmyz_wdkhwl_dhty_fy_hy_lnrjs because Mapped is not 'no'
# Skipping shataa_alula_apartment because Mapped is not 'no'
# Skipping canopy_abha_saudi_arabia because Mapped is not 'no'
# Skipping doubletree_by_hilton_abha_al_marooj because Mapped is not 'no'
# Skipping oyo_348_ruh_taiba_hotel_3 because Mapped is not 'no'
# Skipping novotel_makkah_mashaer_3 because Mapped is not 'no'
# Skipping tulip_inn_hotel_olaya_house because Mapped is not 'no'
# Skipping golden_tulip_andalusia_riyadh because Mapped is not 'no'
# Skipping manazel_al_ain_mercure because Mapped is not 'no'
# Skipping hyatt_hotel_makkah because Mapped is not 'no'
# Skipping mayyun_suites_2 because Mapped is not 'no'
# Skipping delta_suite because Mapped is not 'no'
# Skipping yanbu_avenue_hotel_apartment because Mapped is not 'no'
# Skipping al_olayan_palace because Mapped is not 'no'
# Skipping hotel_safwa_taiba_suite because Mapped is not 'no'
# Skipping dar_rayhaan_by_rotana_al_khobar because Mapped is not 'no'
# Skipping hadab_al_sahafa because Mapped is not 'no'
# Skipping oceanic_khorfakkan_resort_and_spa_fujairah because Mapped is not 'no'
# Skipping hayat_beach because Mapped is not 'no'
# Skipping nawarah_for_hotel_suites_24 because Mapped is not 'no'
# Skipping emaar_international because Mapped is not 'no'
# Skipping kease_qurtubah_a2_royal_design_az48 because Mapped is not 'no'
# Skipping kease_qurtubah_a13_royal_design_az38 because Mapped is not 'no'
# Skipping almutamarat_a1_timeless_history_ag94 because Mapped is not 'no'
# Skipping kease_hittin_n2_lusso_hejaz_ax78 because Mapped is not 'no'
# Skipping kease_hittin_h1_royal_touch_gx97 because Mapped is not 'no'
# Skipping kease_malqa_k8_royal_touch_az61 because Mapped is not 'no'
# Skipping kease_malqa_e9_royal_touch_gz90 because Mapped is not 'no'
# Skipping kease_malqa_d12_royal_touch_gz20 because Mapped is not 'no'
# Skipping alrajhi_qaswarah_residence because Mapped is not 'no'
# Skipping bnbmehomes_2br_with_cinema_room_r42b4 because Mapped is not 'no'
# Skipping kease_yasmin_f1_lusso_hejaz_gx41 because Mapped is not 'no'
# Skipping hittin_b12_latest_development_gx58 because Mapped is not 'no'
# Skipping kease_yasmin_g7_lusso_hejaz_xz72 because Mapped is not 'no'
# Skipping hittin_b10_latest_development_ag22 because Mapped is not 'no'
# Skipping hittin_a8_latest_development_ax62 because Mapped is not 'no'
# Skipping hittin_u11_royal_design_az57 because Mapped is not 'no'
# Skipping dar_rayhaan_by_rotana_al_khobar_4 because Mapped is not 'no'
# Skipping holiday_inn_riyadh_al_qasr_2 because Mapped is not 'no'
# Skipping maro_hotel_3 because Mapped is not 'no'
# Skipping al_shamayil_al_rraqiyah_furnished because Mapped is not 'no'
# Processed almuhaidb_jawazat successfully with giata id: no
# Processed bhr_ryzydns_2_obhur_residence successfully with giata id: no
# Processed tu_jardin_qurtubah successfully with giata id: 936516
# Processed maro_2 successfully with giata id: 1432456
# Processed khayal_hostel_serviced_apartments_2 successfully with giata id: no
# Processed manazel_aldana_serviced_apartments successfully with giata id: 1374373
# Processed raweat_aseer_for_furnished_apartment successfully with giata id: no
# Processed tras_furnished_aparatment successfully with giata id: no
# Processed lota_hotel_self_service successfully with giata id: 1434286
# Processed afaq_tourist successfully with giata id: no
# Processed four_points_by_sheraton_king_abdulaziz successfully with giata id: 1442765
# Processed 4rent_hotel_suites_moroj_alamir_2 successfully with giata id: 707486
# Processed riyadh_star_rooms successfully with giata id: 1088612
# Processed suknai_resort_3 successfully with giata id: 1449612
# Processed aria_resort_2 successfully with giata id: 1420194
# Processed mirada_purple_obhur successfully with giata id: no
# Processed nusk_al_eiman_almadinah_ex_ramada_almadinah successfully with giata id: no
# Skipping lamasat_hotel_apartments because Mapped is not 'no'
# Skipping lebanese_moon_hotel_apartments because Mapped is not 'no'
# Skipping golden_garden_al_corniche because Mapped is not 'no'
# Skipping movenpick_al_nawras_jeddah_family_resort_ because Mapped is not 'no'
# Skipping almuhaidb_tahliya_olaya because Mapped is not 'no'
# Skipping al_eairy_furnished_apt_al_qunfudhah_2 because Mapped is not 'no'
# Skipping al_eairy_furnished_apartments_tabuk_4 because Mapped is not 'no'
# Skipping royal_home_10 because Mapped is not 'no'
# Skipping orooq_al_thahab_al_makkeya because Mapped is not 'no'
# Skipping mirage_hotel_28 because Mapped is not 'no'
# Skipping mada_suites because Mapped is not 'no'
# Skipping snood_remaz_hotel because Mapped is not 'no'
# Skipping sadeem_hotel_suites_2_3 because Mapped is not 'no'
# Skipping qasr_aldabab_housing_units because Mapped is not 'no'
# Skipping nasim_alolya because Mapped is not 'no'
# Skipping sedra_residence_al_khobar because Mapped is not 'no'
# Skipping nada_al_majd_hotel because Mapped is not 'no'
# Skipping rowaa_al_aziziyah because Mapped is not 'no'
# Skipping rwz_brj_lshty_beach_rose_sea_view because Mapped is not 'no'
# Skipping lmlq_tlyd_kmbwnd_htyn_lbwlyfrd because Mapped is not 'no'
# Skipping rkn_lbylsn because Mapped is not 'no'
# Skipping smkh_bytsh_4_grf_brj_lshty_tllh_l_lbhr_mbshrh_wyl_fqt because Mapped is not 'no'
# Skipping burj_al_hayat_furnished_suitesal_mallaz_2 because Mapped is not 'no'
# Processed vivian_park_el_raeid_hotel successfully with giata id: 1433419
# Processed qasr_al_al_aqiq_furnished_units_2 successfully with giata id: 1316902
# Processed nafa_furnished_apartment successfully with giata id: no
# Processed alkhobar_pearl successfully with giata id: no
# Processed dorar_manzly_aparthotel successfully with giata id: no
# Processed mazayya_furnished_apartment successfully with giata id: no
# Processed qasr_alsahab successfully with giata id: no
# Processed villas_lavender successfully with giata id: no
# Processed golden_flower_2 successfully with giata id: no
# Processed ritan_suites successfully with giata id: no
# Processed jkhfurnished_apartment successfully with giata id: no
# Processed rahti_2_furnished_apartments successfully with giata id: no
# Processed clouds_and_stars_furnished_units_2 successfully with giata id: no
# Processed taj_garnada_furnished_apartments successfully with giata id: no
# Processed lamar_serviced_apartments successfully with giata id: no
# Processed rose_furnished_apartments successfully with giata id: no
# Processed althahbia_rahty_serviced_apartments successfully with giata id: no
# Processed nawamis_for_serviced_apartments successfully with giata id: no
# Processed visitor_furnished_apartments successfully with giata id: no
# Processed tu_jardin_al_nahdah successfully with giata id: no
# Processed lottaz_beach successfully with giata id: no
# Processed abella_2 successfully with giata id: no
# Processed beautat_al_samer successfully with giata id: no
# Processed mera_park_hotel_suites successfully with giata id: no
# Processed al_butat_el_motamyza successfully with giata id: 1006636
# Skipping muraysi_hotel_apartments because Mapped is not 'no'
# Skipping manazel_al_ain_mercure_hotel because Mapped is not 'no'
# Skipping diyafat_al_haramain_apartments_2 because Mapped is not 'no'
# Skipping nawara_mohamdia_branch because Mapped is not 'no'
# Skipping nawarah_for_hotel_suites because Mapped is not 'no'
# Skipping crown_town because Mapped is not 'no'
# Skipping al_meshkat_hotel_apartments_2 because Mapped is not 'no'
# Skipping al_khozama_madinah because Mapped is not 'no'
# Skipping rafa_3 because Mapped is not 'no'
# Skipping family_house_hotel because Mapped is not 'no'
# Skipping la_fontaine_al_hamra because Mapped is not 'no'
# Skipping tobal_furnished_apartments because Mapped is not 'no'
# Skipping grand_plaza_jeddah because Mapped is not 'no'
# Skipping oyo_365_oyoon_jeddah_residential_units because Mapped is not 'no'
# Skipping white_suite_aparthotel because Mapped is not 'no'
# Skipping masayef_al_gharbeah_aparthotel because Mapped is not 'no'
# Skipping daw_al_qamar_2 because Mapped is not 'no'
# Skipping nouf_8 because Mapped is not 'no'
# Skipping sunset_suites_17 because Mapped is not 'no'
# Skipping mabaat_al_malqa_613 because Mapped is not 'no'
# Skipping mabaat_al_yasmin_355 because Mapped is not 'no'
# Skipping alatheer_aparthotel because Mapped is not 'no'
# Skipping mabaat_al_malqa_507 because Mapped is not 'no'
# Skipping mabaat_al_malqa_512 because Mapped is not 'no'
# Skipping safwat_al_bait_hotel because Mapped is not 'no'
# Skipping khelewi_al_olaya_apartment because Mapped is not 'no'
# Skipping tlyn_lryd because Mapped is not 'no'
# Skipping suite_blue_2 because Mapped is not 'no'
# Skipping rkn_zdn_1 because Mapped is not 'no'
# Skipping harmony_house_hotel_apartments_2 because Mapped is not 'no'
# Processed bab_samhan_a_luxury_collection_hotel_diriyah successfully with giata id: 1442698
# Skipping diamond_angle_suites because Mapped is not 'no'
# Skipping five_season_hotel because Mapped is not 'no'
# Processed aber_khamis_mushayt_hotel_20km_from_abha successfully with giata id: no
# Processed polaris_furnished_apartments successfully with giata id: no
# Processed ram_jeddah_serviced_apartments_2 successfully with giata id: 1416971
# Processed nilofer_leader_furnished_apartments successfully with giata id: no
# Processed shama_jeddah successfully with giata id: no
# Processed saryat_alhamra_furnished_apartments successfully with giata id: no
# Processed al_asr_almasi_suite_apartments successfully with giata id: no
# Processed msaken_al_jood successfully with giata id: no
# Processed seyof_al_shuhada_hotel successfully with giata id: no
# Processed hailla_inn successfully with giata id: no
# Processed manar_altawheed_1 successfully with giata id: no
# Processed goot_almasif_furnished_apartments successfully with giata id: no
# Processed manazel_qebaa successfully with giata id: no
# Processed nares_plus_alnuzha successfully with giata id: no
# Processed taiba_suites_hotel successfully with giata id: no
# Processed mezab_al_sabeq successfully with giata id: no
# Processed alfakhriah_suites_hotel successfully with giata id: no
# Processed masat_albadr successfully with giata id: 919123
# Processed liwan_alkhaleej successfully with giata id: no
# Processed wharf_palace successfully with giata id: no
# Processed daro_home successfully with giata id: no
# Processed al_joon_furnished_apartments successfully with giata id: no
# Processed blue_tower_hotel_apartments successfully with giata id: no
# Processed beauty_rose_hotel_2 successfully with giata id: no
# Processed green_view_12 successfully with giata id: 1407398
# Processed dar_rafah_furnished_apartments successfully with giata id: no
# Processed dar_hashem_fara_marouj successfully with giata id: no
# Processed night_star_3 successfully with giata id: no
# Processed golden_stone_hotel_3 successfully with giata id: no
# Processed qaser_mobarak_furnished_apartments successfully with giata id: no
# Processed hudua_almasa_furnished_apartments successfully with giata id: no
# Skipping one_to_one_grand_marbia because Mapped is not 'no'
# Skipping garden_millennium_abha_hotel because Mapped is not 'no'
# Skipping zahrat_al_rabea because Mapped is not 'no'
# Skipping golden_square_aparthotels_2_riyadh_road because Mapped is not 'no'
# Processed zaman_homeland successfully with giata id: no
# Processed manarat_al_madinah successfully with giata id: no
# Processed sama_al_amani_hotel successfully with giata id: 1433039
# Processed manazel_maali_suites successfully with giata id: no
# Processed kenan_jeddah successfully with giata id: no
# Processed manazel_forsan successfully with giata id: no
# Processed al_khozama_hotel_residences_kaust successfully with giata id: no
# Processed mnazel_lina_serviced_apartments successfully with giata id: no
# Processed mnazel_ewan_furnished_apartments successfully with giata id: no
# Processed skoon_house_for_furnished_apartment successfully with giata id: no
# Skipping shayah_suites because Mapped is not 'no'
# Processed dar_almadina_furnished_apartments successfully with giata id: no
# Processed diafat_alharmen_dar_alabrar successfully with giata id: no
# Processed regency_jazan_furnished_apartment successfully with giata id: no
# Processing complete. Updated file saved as 'Umrahbooking_updated.xlsx'

# %% [markdown]
# ### Count total ids find.

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('Umrahbooking_updated.xlsx')

# Calculate counts
no_count = (df['giata_present'] == 'no').sum()
nan_count = df['giata_present'].isna().sum()
others_count = len(df) - no_count - nan_count

# Display results
print(f"Number of 'no' entries: {no_count}")
print(f"Number of NaN entries: {nan_count}")
print(f"Number of giata id find: {others_count}")
# Out:
# Number of 'no' entries: 1111
# Number of NaN entries: 7476
# Number of giata id find: 185

# %% [markdown]
# ### Here show all row where giata id is present

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('Umrahbooking_updated.xlsx')

# Calculate counts
no_count = (df['giata_present'] == 'no').sum()
nan_count = df['giata_present'].isna().sum()
others_count = len(df) - no_count - nan_count

print(f"Number of 'no' entries: {no_count}")
print(f"Number of NaN entries: {nan_count}")
print(f"Number of giata id find: {others_count}")

other_rows = df[(df['giata_present'].notna()) & (df['giata_present'] != 'no')]

# Display the filtered rows
print("\nRows with 'other' entries:")
print(other_rows)
# Out:
# Number of 'no' entries: 1111
# Number of NaN entries: 7476
# Number of other entries (e.g., 'yes', 'error'): 185
#
# Rows with 'other' entries:
#                                      Ratehawk Code  \
# 257                      narcissus_the_royal_hotel
# 428                             saja_hotels_makkah
# 467                                     ross_hotel
# 571        le_park_concord_rabwah_boutique_hotel_2
# 601                    nova_m_hotel_edge_by_rotana
# ...                                            ...
# 8720  bab_samhan_a_luxury_collection_hotel_diriyah
# 8725              ram_jeddah_serviced_apartments_2
# 8740                                  masat_albadr
# 8747                                 green_view_12
# 8760                           sama_al_amani_hotel
#
#                                           Hotel name  \
# 257                        Narcissus The Royal Hotel
# 428                               Saja Hotels Makkah
# 467                                       Ross Hotel
# 571                           Le Park Concord Rabwah
# 601                      Nova M Hotel Edge By Rotana
# ...                                              ...
# 8720  Bab Samhan, A Luxury Collection Hotel, Diriyah
# 8725                  RAM Jeddah Serviced Apartments
# 8740                                    Masat Albadr
# 8747                                      Green View
# 8760                             Sama Al Amani Hotel
#
#                                                 Address Country Iso  \
# 257                                     Olaya s, Riyadh          SA
# 428                             Al Kidwah Tunnel, Mecca          SA
# 467                                Al Urubah Rd, Riyadh          SA
# 571                 Alrabwah District, fifa St., Riyadh          SA
# 601    6731 Al Olaya Street, Al Woroud District, Riyadh          SA
# ...                                                 ...         ...
# 8720      7628 King Faisal Ibn Abd Al Aziz Road, Riyadh          SA
# 8725  Setten Rd, Al Bawadi, Jeddah 23531, Saudi Arab...          SA
# 8740  DMPB7483, 7483 Prince Muqrin Ibn Abdulaziz, 46...          SA
# 8747  6753 Rammah, 3347, Al Nasim, Abha 62527, Saudi...          SA
# 8760                             Um Al Qura Road, Mecca          SA
#
#      Hotel country Hotel city  Star rating   latitude  longitude Mapped  \
# 257   Saudi Arabia     Riyadh            5  24.692123  46.686462     NO
# 428   Saudi Arabia      Mecca            0  21.404665  39.826206     NO
# 467   Saudi Arabia     Riyadh            0  24.689240  46.637814     NO
# 571   Saudi Arabia     Riyadh            0  24.703007  46.768078     NO
# 601   Saudi Arabia     Riyadh            0  24.688677  46.688004     NO
# ...            ...        ...          ...        ...        ...    ...
# 8720  Saudi Arabia     Riyadh            5  24.739815  46.572570     NO
# 8725  Saudi Arabia     Jeddah            0  21.600210  39.167900     NO
# 8740  Saudi Arabia     Medina            4  24.485477  39.681650     NO
# 8747  Saudi Arabia       Abha            3  18.210018  42.542896     NO
# 8760  Saudi Arabia      Mecca            3  21.424755  39.815823     NO
#
#      giata_present
# 257        1428454
# 428        1433106
# 467        1427254
# 571        1316096
# 601        1432054
# ...            ...
# 8720       1442698
# 8725       1416971
# 8740        919123
# 8747       1407398
# 8760       1433039
#
# [185 rows x 11 columns]

# %% [markdown]
# ### Creat all id list where giata id only find.

# %%
import pandas as pd

def get_giata_ids(filename):
    """
    Loads the Excel file and returns a list of giata id values from the 'giata_present'
    column where the value is not 'no' and not NaN.
    """
    # Load Excel file
    df = pd.read_excel(filename)
    
    # Filter rows: only keep those where giata_present is not NaN and not 'no'
    filtered = df[(df['giata_present'].notna()) & (df['giata_present'] != 'no')]
    
    # Extract the list of giata id values
    giata_ids = filtered['giata_present'].tolist()
    return giata_ids

# Example usage:
if __name__ == "__main__":
    giata_ids = get_giata_ids('Umrahbooking_updated.xlsx')
    # Print each giata id on a new line
    for giata in giata_ids:
        print(giata)
# Out:
# 1428454
# 1433106
# 1427254
# 1316096
# 1432054
# 1445377
# 1432067
# 1433340
# 1433141
# 1294104
# 1416815
# 1430632
# 137490
# 720456
# 646988
# 928171
# 543839
# 1436629
# 1428455
# 1434876
# 1438113
# 107275
# 1442809
# 962124
# 1442196
# 1364779
# 1430359
# 1433298
# 889460
# 1432634
# 1446436
# 1433043
# 1405993
# 1432565
# 1432574
# 1428330
# 1428238
# 275276
# 1432551
# 503909
# 883830
# 1428549
# 244242
# 1432557
# 1432069
# 1441938
# 1434218
# 1433419
# 718542
# 1441973
# 1432440
# 1434269
# 1332063
# 1364779
# 1294344
# 1433409
# 1441386
# 917914
# 1126273
# 1445380
# 624715
# 1112073
# 919661
# 1442798
# 1396796
# 1457720
# 898354
# 928978
# 1420212
# 1331921
# 987610
# 729974
# 1433008
# 1435374
# 1360253
# 889384
# 1441930
# 1308204
# 968991
# 1428456
# 1396763
# 957702
# 1434121
# 604930
# 707619
# 811090
# 1446500
# 424515
# 707619
# 1364828
# 1441958
# 1433043
# 629095
# 1305626
# 1432534
# 1442211
# 1434302
# 1433275
# 129781
# 1338485
# 1331848
# 1455320
# 1317202
# 877093
# 1025128
# 919114
# 972163
# 918874
# 1456541
# 1359996
# 1428584
# 1007317
# 1237367
# 752475
# 1445400
# 1442603
# 1451339
# 1432073
# 1433280
# 1432065
# 1364692
# 1364841
# 1445350
# 1428214
# 687950
# 957547
# 811267
# 707862
# 1416963
# 1434125
# 1331405
# 716698
# 450987
# 1432465
# 1428430
# 1294162
# 1445385
# 1445429
# 1311345
# 1206130
# 1455335
# 916401
# 1294091
# 1433117
# 1445355
# 1359970
# 1430084
# 1390522
# 108046
# 1442127
# 922743
# 875079
# 1428543
# 1451176
# 1433209
# 927610
# 1433117
# 1445431
# 680572
# 1432712
# 737261
# 1434223
# 714307
# 1433384
# 1447167
# 1428495
# 1442265
# 102363
# 936516
# 1432456
# 1374373
# 1434286
# 1442765
# 707486
# 1088612
# 1449612
# 1420194
# 1433419
# 1316902
# 1006636
# 1442698
# 1416971
# 919123
# 1407398
# 1433039

# %% [markdown]
# ## Create new xlsx file follow 'NO'
# ### Create a xlsx file where giata id is not present but client xlsx file give it not insert global mapping database.

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('Umrahbooking_updated.xlsx')

# Filter rows where 'giata_present' is 'no'
no_rows = df[df['giata_present'] == 'no']

# Save to a new Excel file
no_rows.to_excel('not_find.xlsx', index=False)

print("File 'not_find.xlsx' has been created with rows where 'giata_present' is 'no'.")
# Out:
# File 'not_find.xlsx' has been created with rows where 'giata_present' is 'no'.

# %% [markdown]
# ### Add a column for not finding giata tracking file.

# %%
import pandas as pd

df = pd.read_excel('not_find.xlsx')

df['ratehawk_present'] = None  

df.to_excel('not_find.xlsx', index=False)

print("Column 'ratehawk_present' added successfully!")
# Out:
# Column 'ratehawk_present' added successfully!

# %% [markdown]
# ### Separet 'find_id' and 'not_find_id' in xlsx.

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import text

# Load the Excel file
df = pd.read_excel('not_find.xlsx')

# Add a new column for ratehawk presence
df['ratehawk_present'] = None

# Database connection setup (replace with your actual database URL)
DATABASE_URL = "mysql+pymysql://root:@localhost/csvdata01_02102024"
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()

def check_ratehawk_presence(ratehawk_id, session):
    query = text("SELECT * FROM ratehawk WHERE id = :ratehawk_id")
    result = session.execute(query, {'ratehawk_id': ratehawk_id}).fetchone()
    return 'find' if result is not None else 'not_find'

for index, row in df.iterrows():
    if str(row['Mapped']).strip().lower() != 'no':
        continue
    
    ratehawk_code = row['Ratehawk Code']
    
    presence = check_ratehawk_presence(ratehawk_code, session)
    df.at[index, 'ratehawk_present'] = presence
    print(f"Processed {ratehawk_code} with result: {presence}")

df.to_excel('not_find.xlsx', index=False)
print("Updated file saved as 'not_find.xlsx'")
# Out:
# Processed damac_towers_olaya_by_selsal with result: find
# Processed holiday_suites_al_azizia with result: find
# Processed rose_sharurah_serviced_apartments with result: find
# Processed mirada_purple_al_waha with result: find
# Processed arjan_park_hotel_al_aziziyah with result: find
# Processed al_mabat_serviced_apartments with result: find
# Processed wateel with result: not_find
# Processed samaya_spring_hotel with result: not_find
# Processed towlan_qurtuba_2 with result: find
# Processed wissam_alhawra_hotel with result: find
# Processed rose_plaza_3 with result: find
# Processed karam_aldiafa_hotel_suites with result: find
# Processed jawharat_qasr_al_safwa with result: find
# Processed wissam_garden with result: find
# Processed gp_resort with result: find
# Processed kease_malqa_e1_elegance_ag29 with result: find
# Processed mabaat_alyasmin_555 with result: find
# Processed almiqat_ajyad_hotel with result: find
# Processed arjaan_park_al_shifa_hotel with result: not_find
# Processed yaqoot_al_madina_suites with result: not_find
# Processed guests_inn_hotel with result: not_find
# Processed diaara_hotel with result: not_find
# Processed kease_ar_rabi_d31_elegance_ax47 with result: not_find
# Processed mabaat_hittin_568 with result: not_find
# Processed ketzal with result: not_find
# Processed hotel_ten_qurtubah_hotel with result: not_find
# Processed the_land_resort with result: not_find
# Processed pilo_serviced_apartment with result: not_find
# Processed snood_al_huda_hotel with result: not_find
# Processed selat_al_bait_hotel with result: not_find
# Processed park_royal_ex_rehab_almultaqa with result: not_find
# Processed moumlvenpick_hotel_waad_al_shamal_5_stars with result: not_find
# Processed mayar_apartment with result: not_find
# Processed milan_park_hotel_fndq_myln_brk with result: not_find
# Processed anwar_almokhtar_1 with result: not_find
# Processed dior_furnished_apartments with result: not_find
# Processed alwaha_alalya_furnished_apartment with result: not_find
# Processed albidaa_furnished_apartments with result: not_find
# Processed watheer_furnished_apartments with result: not_find
# Processed brown_house_6 with result: not_find
# Processed darna_furnished_apartment with result: not_find
# Processed alsultan_inn_hotel with result: not_find
# Processed royal_palace_26 with result: not_find
# Processed itqan_hotel with result: not_find
# Processed rwasel_alnakhla_furnished_apartments with result: not_find
# Processed kins_aljawda with result: not_find
# Processed fanen_suites_furnished_apartments with result: not_find
# Processed raghad_almadinah_hotel with result: not_find
# Processed nuzha_residential_units with result: not_find
# Processed laylati_alyarmuk_tariq_aldamaam with result: not_find
# Processed saif_plus_2 with result: not_find
# Processed oasis_rise with result: not_find
# Processed amber_hospitality_al_rawdah with result: not_find
# Processed vip_resort_chalet_24 with result: not_find
# Processed fahkamit_al_yamama_fkhm_lymm_llshqq_lfndqy with result: not_find
# Processed el_afraa_hotel with result: not_find
# Processed diafat_al_harmen_dar_al_jamaia with result: not_find
# Processed diafat_al_harmen_dar_ben_dehish with result: not_find
# Processed lulua_albashaer with result: not_find
# Processed kawthar_albaraka with result: not_find
# Processed kawtar_alkhair with result: not_find
# Processed al_rayyan_almakiyah_towers_4_hotel with result: not_find
# Processed sedra_makkah with result: not_find
# Processed rabwat_al_safwah_golden_hotel with result: not_find
# Processed rose_plaza_almashgal_hotel with result: not_find
# Processed doret_alwesam with result: not_find
# Processed hoor_aseer with result: not_find
# Processed durrat_alsharq with result: not_find
# Processed lviv_hotel with result: not_find
# Processed alzahraa with result: not_find
# Processed hamza with result: not_find
# Processed houses_albahia with result: not_find
# Processed brant_chalets with result: not_find
# Processed rahat_taraf_furnished_apartments_2 with result: not_find
# Processed al_rowad_owners with result: not_find
# Processed al_jazeera_towers_furnished_apartments with result: not_find
# Processed qasser_al_mokhmalia with result: not_find
# Processed alzidan with result: not_find
# Processed masat_darkom_1_serviced_apartments with result: not_find
# Processed telal_alward_furnished_apartments with result: not_find
# Processed al_ayka_hotel_suites with result: not_find
# Processed borg_el_ward_furnished_apartments with result: not_find
# Processed layali_alraha_furnished_apartments with result: not_find
# Processed rahti_home_furnished_apartments with result: not_find
# Processed nuzul_tawaroun with result: not_find
# Processed analah_resort with result: not_find
# Processed arqada with result: not_find
# Processed roken_alanwar_furnished_apartments with result: not_find
# Processed fares_home_furnished_apartments with result: not_find
# Processed moments_furnished_apartments with result: not_find
# Processed ahleen_4 with result: find
# Processed asala_al_shorouk_2 with result: find
# Processed rowaa_al_aziziyah_hotel with result: find
# Processed s_maskan_hotel with result: find
# Processed stone_village_resort with result: find
# Processed dyar_omar with result: find
# Processed al_yamama_palace_furnished_apartments_aktham_branch with result: find
# Processed al_qasr_palace_furnished_apartments with result: find
# Processed golden_salsabel with result: find
# Processed alwahda_hotels_2 with result: find
# Processed aseel_suites with result: find
# Processed happiness_suites_serviced_apartments with result: find
# Processed kease_hittin_b5_royal_touch_xz63 with result: find
# Processed mabaat_al_malqa_547 with result: find
# Processed sunrise_suites_8 with result: find
# Processed paradise_al_madinah_hotel with result: not_find
# Processed gawaher_al_sharq with result: not_find
# Processed malafkum with result: not_find
# Processed nour_sama with result: not_find
# Processed bnbmb_alkhawaled7_3bdr_apartments with result: not_find
# Processed noor_amal_apartments_serviced_2 with result: not_find
# Processed aljawder with result: not_find
# Processed albat_darak_furnished_apartment with result: not_find
# Processed liali_alnil with result: not_find
# Processed skoot_furnished_apartment with result: not_find
# Processed sace_alolia with result: not_find
# Processed mogam3_alkhozama with result: not_find
# Processed chalet_toot_alrifia with result: not_find
# Processed lourde_furnished_units with result: not_find
# Processed doze_furnished_apartments with result: not_find
# Processed semo_tower_furnished_apartments with result: not_find
# Processed lyali_soknana_furnished_apartments with result: not_find
# Processed ghazaly_serviced_apartment with result: not_find
# Processed albakry_apartment with result: not_find
# Processed randa_cities_serviced_apartments with result: not_find
# Processed al_hamara_park with result: not_find
# Processed rana_house with result: not_find
# Processed luliwat_al_arbeyn with result: not_find
# Processed nayrouz_riyadh_furnished_apartments with result: not_find
# Processed sunway_tabuk_hotel with result: find
# Processed ehdaa_hotel_makkah with result: not_find
# Processed wadf_serviced_apartments with result: not_find
# Processed beautat_almarwa with result: not_find
# Processed alharyra_furnished_apartments with result: not_find
# Processed almaalei_furnished_apartments with result: not_find
# Processed alhemdanya with result: not_find
# Processed rand_jeddah with result: not_find
# Processed aknan_elsafa with result: not_find
# Processed toot_house_2_furnished_apartments with result: not_find
# Processed amasyna_chalets with result: not_find
# Processed al_mahmal_hotel_suites with result: not_find
# Processed damas_hotel with result: not_find
# Processed mirada_purple_alwaha with result: not_find
# Processed amber_hospitality_al_qirawan with result: not_find
# Processed my_room_12 with result: not_find
# Processed guanahotel with result: not_find
# Processed alhudu_apartments with result: not_find
# Processed hotel_jawhara with result: not_find
# Processed diafat_al_haramen_1 with result: not_find
# Processed guar_al_beit with result: not_find
# Processed al_nahdi_al_shohda with result: not_find
# Processed sama_alkhair_hotel with result: not_find
# Processed hamad_saif_batal_hotel with result: not_find
# Processed taif_al_nebras_hotel with result: not_find
# Processed iwan_teba with result: not_find
# Processed albidaa_elsallam with result: not_find
# Processed hamsat_fajir with result: not_find
# Processed nathaq_alwatan with result: not_find
# Processed nozul_fadan with result: not_find
# Processed zawiat_amasina_for_furnished_apartments with result: not_find
# Processed taj_almakan with result: not_find
# Processed ivan_suites with result: not_find
# Processed the_artisan_residence with result: not_find
# Processed al_nargs_pear with result: not_find
# Processed nozol_yusr_furnished_units with result: not_find
# Processed life_residence_furnished_apartments with result: not_find
# Processed ellil_lek_serviced_apartments with result: not_find
# Processed dar_shemh with result: not_find
# Processed taif_layan_furnished_apartments with result: not_find
# Processed almasa_corner with result: not_find
# Processed moon_tree_serviced_apartments with result: not_find
# Processed erth_al_asala with result: not_find
# Processed rose_tulip_serviced_apartments with result: find
# Processed lmeek_serviced_apartments with result: not_find
# Processed alfanar_villa_by_auris with result: not_find
# Processed ninety_two with result: not_find
# Processed ward_furnished_apartments with result: not_find
# Processed north_wind with result: not_find
# Processed ajnahit_waref with result: not_find
# Processed selsabel_hammoda_hotel with result: not_find
# Processed beauty_ryan with result: not_find
# Processed wisam_al_taj_hotel with result: find
# Processed dn_gdyr_llwhdt_lskny_dana_aghadir_serviced_apartements with result: find
# Processed suknai_resort with result: find
# Processed nomas_palace_apparthotel_al_wadyan with result: find
# Processed imagin_resort with result: find
# Processed hotel_corp_yanbu_hotel with result: find
# Processed sands_inn_hostel with result: find
# Processed vip_resort_chalet_18 with result: not_find
# Processed room_rent_2 with result: not_find
# Processed fndq_hwlydy_lkhlyj_lryd_holiday_al_khaleej_hotel with result: not_find
# Processed lavina_suites with result: not_find
# Processed palm_tree_4 with result: not_find
# Processed mnazel_maale with result: not_find
# Processed snood_al_maaly_hotel with result: not_find
# Processed nojoom_alsharqia with result: not_find
# Processed danah_alsharqia with result: not_find
# Processed acadonia with result: not_find
# Processed jnan_alsharq with result: not_find
# Processed bodor_alsharq_3 with result: not_find
# Processed world_of_violet with result: not_find
# Processed royal_palace_25 with result: not_find
# Processed tobal_residence with result: not_find
# Processed villa_misk_hotel_apartments with result: not_find
# Processed roz_aljawhra_furnished_apartments with result: not_find
# Processed swat_hotel_apartments_2 with result: not_find
# Processed abha_lamar_3_furnished_apartments with result: not_find
# Processed hayat_plus_furnished_apartments with result: not_find
# Processed golden_squaer with result: not_find
# Processed mabaat_al_nada_522 with result: not_find
# Processed safwat_al_bait_al_mahbas with result: not_find
# Processed nine_nights_chalet_for_families with result: not_find
# Processed namaa_furnished_suites with result: not_find
# Processed dar_kanan_furnished_apartments with result: not_find
# Processed loren_suites_3 with result: not_find
# Processed jeddah_luxury_stay_furnished_apartments with result: not_find
# Processed grand_safir_hotel_apartments with result: not_find
# Processed alfalah_residence with result: not_find
# Processed nour_al_safwah_4 with result: not_find
# Processed ewg_almihbas_hotel with result: not_find
# Processed nuzl_alhijaz_4 with result: not_find
# Processed rushan_aldar with result: not_find
# Processed jawharat_quba with result: not_find
# Processed dar_almolok_furnished_apartments with result: not_find
# Processed dara_jazan_for_furnished_apartments with result: not_find
# Processed golden_daan_hotel with result: not_find
# Processed hotel_sun_set with result: not_find
# Processed lacasa_hotel_apartments with result: not_find
# Processed darr_daraya with result: not_find
# Processed njmet_taleen_furnished_apartments with result: not_find
# Processed rahaty_sweets with result: not_find
# Processed najemt_khail with result: not_find
# Processed rokn_buytat_furnished_apartments with result: not_find
# Processed daryna_furnished_apartments with result: not_find
# Processed happiness_time_chalets with result: not_find
# Processed aal_for_furnished_units with result: not_find
# Processed caddy_albaha_furnished_apartments with result: not_find
# Processed tamiz_al_aqama_for_furnished_apartment with result: not_find
# Processed altaif_gate_furnished_apartments with result: not_find
# Processed alquba_palace with result: not_find
# Processed al_badeel_furnished_apartments with result: not_find
# Processed shahlaa_apartment with result: not_find
# Processed ruken_al_anwar with result: not_find
# Processed la_rive_hotel_suites_ex_ghosn_al_banafsej with result: not_find
# Processed manazel_aldiafah_serviced_apartments_alsulymaniyah with result: not_find
# Processed zouk_alkhayal with result: not_find
# Processed hams_elsehab with result: not_find
# Processed lucerne_chalate with result: not_find
# Processed fakhr_yanbu_2_furnished_apartments with result: not_find
# Processed akaber_al_hijra with result: find
# Processed al_ayyam_hotel with result: find
# Processed flower1_almughrizat with result: find
# Processed mabaat_qurtubah_554 with result: find
# Processed royal_lazure_resort with result: find
# Processed kease_narjis_e12_timeless_history_gx62 with result: not_find
# Processed afaq_al_sahari with result: not_find
# Processed hotelier_suites_by_cantonal with result: not_find
# Processed kease_ar_rabi_d32_elegance_az37 with result: not_find
# Processed door_alkhozama with result: not_find
# Processed grand_regis with result: not_find
# Processed zamazem_alrawda with result: find
# Processed round_furnished_apartment with result: not_find
# Processed shada_furnished_apartment with result: not_find
# Processed danar_2_furnished_apartments with result: not_find
# Processed lian_villas_resort with result: not_find
# Processed moon_light_resort with result: not_find
# Processed nasaem_alkhalij_furnished_apartment with result: not_find
# Processed maui_serviced_apartments with result: not_find
# Processed kawthar_almahaba_furnished_apartments with result: not_find
# Processed rabee_rafal_4_furnished_apartments with result: not_find
# Processed dar_for_serviced_apartments with result: not_find
# Processed jumeirah_homes with result: not_find
# Processed kyona_hotel with result: not_find
# Processed ghaima_aparthotel with result: not_find
# Processed elite_hotelcorniche_branch with result: not_find
# Processed farah_residential_units with result: not_find
# Processed zuwara_hotel_apartments with result: not_find
# Processed tiara_residential_apartments with result: not_find
# Processed qasr_althahr with result: not_find
# Processed alreef_homes_hotel with result: not_find
# Processed marina_palace_furnished_apartments with result: not_find
# Processed al_nuzha with result: not_find
# Processed farha_alalamieh_3_furnished_apartments with result: not_find
# Processed smo_alshafa_furnished_apartments with result: not_find
# Processed tiara_2 with result: not_find
# Processed elite_al_andalos with result: not_find
# Processed al_masem_hotelking_fahad_district with result: not_find
# Processed coov_hotel with result: not_find
# Processed awa with result: not_find
# Processed alfkhama with result: not_find
# Processed new_family_flat_in_taif with result: not_find
# Processed taj_al_hamra_hotel with result: not_find
# Processed diafat_al_haramen2 with result: not_find
# Processed areej_makkah with result: not_find
# Processed kayan_building_1 with result: not_find
# Processed nuzl_alhijaz_2 with result: not_find
# Processed mass_hotel_apartments with result: not_find
# Processed hemmam_furnished_apartments with result: not_find
# Processed suite_elaf with result: not_find
# Processed hayat_jazan_furnished_apartments with result: not_find
# Processed rokn_algwza with result: not_find
# Processed fakhama_almasiya with result: not_find
# Processed albaida_albukhari_suites_2 with result: not_find
# Processed hodua_hotel_suites with result: not_find
# Processed anwar_chalets with result: not_find
# Processed reef_abha_resort with result: not_find
# Processed kayan_al_bustan_serviced_apartments with result: not_find
# Processed rokn_alroshin_furnished_apartments with result: not_find
# Processed kaser_dorat_alalmasa with result: not_find
# Processed riyada_home_serviced_apartments with result: not_find
# Processed nozol_khayal_jizan_for_serviced_apartments with result: find
# Processed rose_najd_serviced_apartment with result: find
# Processed rolana_2 with result: not_find
# Processed aman_hotel_almansik with result: not_find
# Processed hayat_al_riyadh_washam_hotel with result: not_find
# Processed abahi_aparthotel_3 with result: not_find
# Processed amaken_for_furnished_apartments with result: not_find
# Processed sama_el_khamis with result: not_find
# Processed basamat_alsharq_3 with result: find
# Processed al_masaa_aparthotel with result: find
# Processed maskn_el_jawad with result: not_find
# Processed almassa_hotel_2 with result: not_find
# Processed ajneht_romance with result: not_find
# Processed wasn_suits_furnished_apartments with result: not_find
# Processed arica_hotel_apartments with result: find
# Processed al_baida_suites_company_for_serviced_apartments with result: not_find
# Processed seiba_hotel_apartmentsriyadh with result: not_find
# Processed so_sweet_stay_altawun_3br_apartment_with_balcony_garden_view_lqm_ljmyl_shq_fndqy_fkhr_blkwnh_mtlh_lhdyqh with result: find
# Processed msharef_al_moden_hotel with result: find
# Processed rawdat_elmolaby with result: find
# Processed vender_hotel with result: find
# Processed renee_suite with result: find
# Processed mabaat_lulwa_suites_hut_551 with result: find
# Processed durrat_al_ahbab_hotel with result: not_find
# Processed etlalet_ebhar_serviced_apartments with result: not_find
# Processed zresidence_by_dayf with result: not_find
# Processed fndq_zhr_llfndr with result: not_find
# Processed open_aparthotel with result: not_find
# Processed al_tamyoz_al_sharqy_hotel with result: not_find
# Processed taj_al_khalej with result: not_find
# Processed duraht_al_faisaliah_furnished_apartments with result: not_find
# Processed ahla_amasy_furnished_apartment with result: not_find
# Processed dream_here with result: not_find
# Processed blend_furnished_apartments with result: not_find
# Processed victory_royal_hotel with result: not_find
# Processed bodor_alsharq with result: not_find
# Processed itab_al_khobar with result: not_find
# Processed qamet_najd_furnished_apartments with result: not_find
# Processed toot_house_elwessam with result: not_find
# Processed almaadar_park with result: not_find
# Processed mourouj_al_olaya with result: not_find
# Processed takala_furnished_apartments with result: not_find
# Processed anmaz_furnished_apartments with result: not_find
# Processed alaryga_alymama_palace_furnished_apartments with result: not_find
# Processed rose_najran_furnished_apartments with result: not_find
# Processed nuzol_sraya_villa with result: not_find
# Processed zohor_albanafsg with result: not_find
# Processed whdat_alreiad with result: not_find
# Processed castle_hotel_46 with result: not_find
# Processed demure with result: not_find
# Processed aljoud_furnished_apartments with result: not_find
# Processed rolana with result: not_find
# Processed abeer_story_for_serviced_apartments with result: not_find
# Processed luxury_apartments_in_damac_tower_riyadh with result: not_find
# Processed amber_hospitality_izdihar with result: not_find
# Processed holiday_plus_tabba_apartments with result: not_find
# Processed al_asemah_hotel_2 with result: not_find
# Processed sariyah_al_safa_hotel with result: not_find
# Processed dar_lamar_hotel with result: not_find
# Processed salam_lights_hotel with result: not_find
# Processed diyar_al_medina_hotel with result: not_find
# Processed balansia_hotel with result: not_find
# Processed alnakhil_suits with result: not_find
# Processed almadain_hotel with result: not_find
# Processed qasr_wasan_2 with result: not_find
# Processed durrat_al_orouba_furnished_apartments with result: not_find
# Processed doret_sanam with result: not_find
# Processed nassim_abha with result: not_find
# Processed kayan_hotel_abha with result: not_find
# Processed view_park_furnished_apartments with result: not_find
# Processed durah_sanam_hotel with result: not_find
# Processed reyoof_leen with result: not_find
# Processed tolan_furnished_apartments with result: not_find
# Processed alsahab_house with result: not_find
# Processed layl_qurtoba_6_furnished_apartments with result: not_find
# Processed rest_day_furnished_apartments with result: not_find
# Processed ajnht_start with result: not_find
# Processed kara_hotel with result: find
# Processed masarat_al_mashaer with result: find
# Processed hayat_town_3 with result: find
# Processed rabiat_al_hijaz_6 with result: not_find
# Processed fndq_blyt_myrj_lfkhr_palette_luxury_mirage_hotel with result: not_find
# Processed quiet_seven with result: not_find
# Processed vasa_plus_hotel with result: not_find
# Processed golden_new_hotel with result: not_find
# Processed radisson_blu_hotel_dhahran_3 with result: not_find
# Processed al_lazurd_palace with result: not_find
# Processed fakhamet_aljawhrah_for_furnished_apartments with result: not_find
# Processed five_seasons_hotel_spa with result: not_find
# Processed al_reem_homes_for_serviced_apartments with result: not_find
# Processed the_westin_jeddah_2 with result: not_find
# Processed amana_alfakhera_furnished_unit_2 with result: not_find
# Processed lyan_resort with result: find
# Processed kease_qurtubah_a6_royal_design_gx74 with result: find
# Processed kease_malqa_d206_elegance_ag82 with result: find
# Processed hyatt_buyutat_furnished_apartment with result: find
# Processed arca_almasakin with result: find
# Processed family_home_furnished_apartments with result: find
# Processed taj_saba with result: find
# Processed altawfeeg_hotel_azizyah with result: find
# Processed al_ghazali_suites with result: find
# Processed alkrrani_serviced_apartments with result: find
# Processed alprans_aldahabi with result: find
# Processed al_jawharah_for_apartment_units with result: find
# Processed wave_resort_4 with result: not_find
# Processed manzel_aram_105 with result: not_find
# Processed golden_rest_time with result: not_find
# Processed kease_yasmin_b11_elegance_ax41 with result: not_find
# Processed kease_hittin_b14_pop_palette_gx20 with result: not_find
# Processed dania_towers with result: not_find
# Processed almahmoud_furnished_apartment with result: not_find
# Processed nozul_alfyroz with result: not_find
# Processed madeira_furnished_apartments with result: not_find
# Processed makarem_residence with result: not_find
# Processed sara_swites with result: not_find
# Processed danar_4_furnished_apartments with result: not_find
# Processed basmat_alshrqyah_3_furnished_apartments with result: not_find
# Processed layl_alfalah_furnished_apartments with result: not_find
# Processed bait_salsabeel_for_furnished_apartment with result: not_find
# Processed bearl_altor_furnished_apartments with result: not_find
# Processed paradise_furnished_apartments with result: not_find
# Processed reef_suites with result: not_find
# Processed al_corniche_2 with result: not_find
# Processed qasr_al_thuraya_furnished_apartments with result: not_find
# Processed julanar_asharq_suites with result: not_find
# Processed fadet_talla_serviced_apartment_2 with result: find
# Processed mona_houses_furnished_apartments with result: not_find
# Processed laten_suites_alsalim_plaza with result: not_find
# Processed dar_lavina with result: not_find
# Processed dar_lavona with result: not_find
# Processed al_muhaidib with result: not_find
# Processed nazel_alhajjaz_3 with result: not_find
# Processed zamazem_miral with result: not_find
# Processed mithaq_al_huda with result: not_find
# Processed nuzol_alhijaz_7 with result: not_find
# Processed amal_apartment with result: not_find
# Processed yan_furnished_apartments with result: not_find
# Processed elsad_alkhalji_hotel with result: not_find
# Processed al_awail_golden_hotel with result: not_find
# Processed lilia_serviced_apartments with result: not_find
# Processed al_madinh_salsabel with result: not_find
# Processed sliver_salsabel with result: not_find
# Processed albidaa_alshmaly with result: not_find
# Processed paradise_inn_52 with result: not_find
# Processed house_stunning_residential_units with result: not_find
# Processed rozina_albidaa with result: not_find
# Processed golden_buraq_hotel with result: not_find
# Processed alaman_furnished_apartment with result: not_find
# Processed anwar_ohud with result: not_find
# Processed yamama_rwabi with result: not_find
# Processed shuhala_almurwj with result: not_find
# Processed reef_qurtoba with result: not_find
# Processed makarem_furnished_apartment with result: not_find
# Processed hekaya_hotel with result: not_find
# Processed best_rest_resort with result: not_find
# Processed durr_misk_residential_units with result: not_find
# Processed shams_alkhayal with result: not_find
# Processed tawariq_1_serviced_apartments with result: find
# Processed tawariq_2_serviced_apartments with result: find
# Processed khozama_al_riyadh_furnished_apartment with result: find
# Processed wajehat_al_tamayuz_serviced_apartments_1 with result: find
# Processed makarem_najd_5_al_aqiq with result: not_find
# Processed hikayet_abeer_hotel_suites with result: not_find
# Processed laylati_dhahrat_laban with result: not_find
# Processed garden_millennium_ahad_rafidah with result: not_find
# Processed atlantic_platinum_resort with result: not_find
# Processed cities_inn_furnished_apartments with result: not_find
# Processed alshamkha_furnished_apartment with result: not_find
# Processed the_address_furnished_apartment with result: not_find
# Processed nour_al_safwah_3 with result: not_find
# Processed damac_aljawharah_2_bedrooms_apartment_16_floor_with_sea_view_jacuzzi_shq_grftyn_nwm_w_sl_fy_ldwr_16m_jkwzy_l_lbhr with result: find
# Processed kease_al_qairawan15_royal_touch_gx85 with result: find
# Processed foothills_luxury_residence with result: not_find
# Processed vivienda_hada_residence with result: find
# Processed oriens_hotel with result: find
# Processed holiday_furnished_apartment with result: find
# Processed khayal_hostel_serviced_apartments with result: find
# Processed al_qasr_hotel_suites_al_badeea with result: find
# Processed al_rayan_almakiyah_towers_hotel_3 with result: find
# Processed al_muhaidb_residence_jawazat with result: find
# Processed fakhama_al_salamah with result: find
# Processed crown_suite with result: find
# Processed rabiat_al_hijaz_5 with result: find
# Processed kease_yasmin_e3_royal_touch_gx80_2 with result: find
# Processed kease_malqa_b507_royal_design with result: find
# Processed almarzam_towers_hotel with result: find
# Processed la_richy_hotel_apartment with result: find
# Processed arjan_park_hotel_zaharah_laban with result: not_find
# Processed mabaat_al_nakheel_twin_tower_564 with result: not_find
# Processed ziara with result: not_find
# Processed relax_day_hotel_2 with result: not_find
# Processed brj_ljnwb_jwldn_nyw_khmys_mshyt with result: not_find
# Processed shorfa_alsahfa_hotel with result: not_find
# Processed sama_al_qasr_almuhammadiah with result: not_find
# Processed arjan_park1 with result: not_find
# Processed al_tayf_almosafer with result: not_find
# Processed blue_sand_bailsan with result: not_find
# Processed quite_night with result: not_find
# Processed lavona_1 with result: not_find
# Processed layali_albondqia_furnished_apartments with result: not_find
# Processed massayf_alkhobar with result: not_find
# Processed ilaf_eastern_furnished_apartments with result: not_find
# Processed fazah_for_furnished_apartment with result: not_find
# Processed in_taibah_apartment with result: not_find
# Processed tree_seasons_chalets with result: not_find
# Processed rekam_resort_and_chalets with result: not_find
# Processed the_new_vision_hotel with result: not_find
# Processed diar_al_khalidiya_hotel_by_park_regis with result: find
# Processed dyar_almnar with result: not_find
# Processed wajihat_altamyuz_furnished_apartments with result: not_find
# Processed alnahdah with result: not_find
# Processed moments_hotel with result: not_find
# Processed lottaz_alsalama with result: not_find
# Processed dora_ashoor with result: not_find
# Processed aparthotel_ollya_riyadh with result: not_find
# Processed olaya_1_stella_stays with result: not_find
# Processed fakhama_el_nasem with result: not_find
# Processed wasan_al_sharq_wings with result: not_find
# Processed ahlin_suites_3 with result: not_find
# Processed albaida_albukhari_branch2 with result: not_find
# Processed vip_resort_chalet_25 with result: not_find
# Processed ezz_hotel_apartments with result: not_find
# Processed kurtuba_al_azizya_hotel_1 with result: not_find
# Processed kayan_3 with result: not_find
# Processed kawthar_almashaer with result: not_find
# Processed ewg_almechaar_sedky_hotel with result: not_find
# Processed seef_plus_hotel with result: not_find
# Processed pearl_hadeel_furnished_apartments with result: not_find
# Processed ghaleyt_ohoud with result: not_find
# Processed shomoukh_almadineh with result: not_find
# Processed dorat_al_aroos with result: not_find
# Processed milan_suite with result: not_find
# Processed aseel_oasis with result: not_find
# Processed kyona_alazizyah with result: not_find
# Processed alzahra_alraqi_hotel with result: not_find
# Processed aylool_for_furnished_apartments with result: not_find
# Processed jude_suites with result: not_find
# Processed amer_apartments with result: not_find
# Processed khalijiya_almashal_furnished_apartments with result: not_find
# Processed alshumoukh_alraqyah_furnished_apartments with result: not_find
# Processed doolv_for_furnished_apartment with result: not_find
# Processed first_suite with result: not_find
# Processed mnazlna_1_furnished_apartments with result: not_find
# Processed le_reve_hotel with result: find
# Processed masa_al_majd_hotel with result: find
# Processed permanent_luxury_of_furnished_residential_units with result: find
# Processed manazel_al_zahraa_hotel with result: find
# Processed wajahh_atmaiz_2_furnished_apartments with result: not_find
# Processed alrashed_park with result: not_find
# Processed zahrat_alandalus_apartments with result: not_find
# Processed pearl_najd_for_serviced_apartments with result: not_find
# Processed diwan_alaseel_alraqi_furnished_apartments with result: not_find
# Processed adwaa_almadina_hotel with result: not_find
# Processed tera_hotel_gaza with result: not_find
# Processed nuzol_alhijaz5 with result: not_find
# Processed al_ritz_al_madinah with result: find
# Processed rfal_tower_hotel with result: find
# Processed al_aydhi_for_furnished_apartment with result: find
# Processed samit_inn_hotel with result: find
# Processed lamar_ajyad_hotel_1 with result: find
# Processed alnada_palace with result: find
# Processed manazeli_al_corniche_hotel_2 with result: not_find
# Processed kanaf_hotel with result: not_find
# Processed anan_hotel_by_snood with result: not_find
# Processed mezzab_al_sabeq with result: not_find
# Processed hms_llshqq_lmfrwsh with result: not_find
# Processed white_diamond_hotel_sari with result: not_find
# Processed rixos_obhur_jeddah with result: not_find
# Processed almuhaidb_altakhassusi_abaqrino with result: not_find
# Processed amwaj_furnished_apartments_2 with result: not_find
# Processed mkani_furnished_apartments with result: not_find
# Processed biet_almasra_6 with result: not_find
# Processed samaya_al_khobar_hotel with result: not_find
# Processed mian_furnished_apartments with result: not_find
# Processed sama_al_qasar_khorais_furnished_apartments with result: not_find
# Processed msaken_alatlal_furnished_apartments with result: not_find
# Processed blanty_hotel_units with result: not_find
# Processed amarlis_furnished_apartment with result: not_find
# Processed fakhama_rahti with result: not_find
# Processed diafah_apart_hotel with result: not_find
# Processed red_rosa with result: not_find
# Processed self_check_in_and_luxurious_apartments with result: find
# Processed bnbme_riviera34_2_bdr_apartments with result: not_find
# Processed whdat_alreiad_2 with result: not_find
# Processed different_hotel with result: find
# Processed lulu_alsafa_serviced_apartments with result: not_find
# Processed green_house_resort_7 with result: not_find
# Processed one_night_furnished_apartments with result: not_find
# Processed alnasma_alhada with result: not_find
# Processed diwan_alkhalij with result: not_find
# Processed joan_gold_for_furnished_apartments with result: not_find
# Processed masharef_alfakhama_jed with result: not_find
# Processed arjan_qurtuba_serviced_apartments with result: not_find
# Processed gold_inn_riyadh with result: not_find
# Processed awtad_united_hotel with result: not_find
# Processed mawten_lamar_hotel with result: not_find
# Processed alwafaq_almashaer_hotel with result: not_find
# Processed elfadly with result: not_find
# Processed astbrg_almasi with result: not_find
# Processed malath_almasi_hotel with result: not_find
# Processed dream_half_hotel with result: not_find
# Processed alsafiaa_hotel with result: not_find
# Processed paradise_international_hotel_3 with result: not_find
# Processed tu_garden_taiba with result: not_find
# Processed alahmady with result: not_find
# Processed aljawhara_houses with result: not_find
# Processed daan_hotel with result: not_find
# Processed rosa_grand_2 with result: not_find
# Processed alnamareq_almurihah_furnished_apartments with result: not_find
# Processed jeet_al_narjes with result: not_find
# Processed alberthon_furnished_apartments with result: not_find
# Processed golden_dune_al_malaz with result: find
# Processed chalet_toot_alrifia_2 with result: not_find
# Processed nesmt_al_maghreb_furnished_apartments with result: not_find
# Processed remas_jeddah with result: not_find
# Processed al_kaulafaa_almasy_hotel with result: not_find
# Processed sidra_alalia_golden_hotel with result: not_find
# Processed lamsat_nassir with result: not_find
# Processed manazeil_taibah with result: not_find
# Processed almohaydb with result: not_find
# Processed oroub_al_forsan_furnished_apartments with result: not_find
# Processed rayana_palace with result: not_find
# Processed diamond_homes_2_furnished_apartments with result: not_find
# Processed roshen_almasi_serviced_apartments with result: not_find
# Processed sama_altaif with result: not_find
# Processed sobat_hotel_suites with result: not_find
# Processed makan_hotel with result: not_find
# Processed diyar_tabah_hotel with result: not_find
# Processed ahleen_5 with result: find
# Processed albaida_albukhari_residential_units_branch_2 with result: find
# Processed tamaya_alkhobar with result: not_find
# Processed laylati_al_hamra with result: find
# Processed karim_hotel_khobar_2 with result: find
# Processed razord_plaza with result: find
# Processed wahat_al_olia_furnished_apartments with result: find
# Processed silvana_aparthotel with result: find
# Processed hayat_alfursan_for_apartments_hotel with result: find
# Processed danahotleresidences2 with result: find
# Processed almaria_residence with result: find
# Processed fantasy_serviced_apartments_2 with result: not_find
# Processed moltqa_alarab_furnished_apartments with result: not_find
# Processed deyala_serviced_apartments_3 with result: not_find
# Processed riyadh_view_resort with result: not_find
# Processed almuhaidb_olaya_suites with result: not_find
# Processed the_land_resort_ammaria with result: not_find
# Processed anwar_najd with result: find
# Processed rwaya_hotel with result: find
# Processed borg_al_ganoub_furnished_apartments with result: find
# Processed sahabat_taiba with result: find
# Processed diamond_corners_al_hamra with result: find
# Processed mirada_purple_ubhor with result: find
# Processed saeadati_serviced_apartments with result: find
# Processed hotel_apartments_in_burj_damac with result: find
# Processed nakhil_moon_serviced_apartments with result: not_find
# Processed razana_al_rawadha_hotel with result: not_find
# Processed golden_new_al_dar_hotel_apartments with result: not_find
# Processed blend_hotel_suites_2 with result: not_find
# Processed iiiashgan_furnished_apartment with result: not_find
# Processed natwan_furnished_apartment with result: not_find
# Processed al_forsana_restort with result: not_find
# Processed shorft_alkhalig with result: not_find
# Processed rose_neiry_furnished_apartment_2 with result: not_find
# Processed sea_inn with result: not_find
# Processed padova_furnished_apartment with result: not_find
# Processed dar_alkhial with result: not_find
# Processed injaz_inn_furnished_apartment with result: not_find
# Processed sama_serviced_apartments with result: not_find
# Processed dar_daken_furnished_apartments with result: not_find
# Processed danet_muhayil_furnished_apartments with result: not_find
# Processed baida_hotel with result: not_find
# Processed nour_almnazel_furnished_apartment with result: not_find
# Processed hira_star_furnished_apartments with result: not_find
# Processed stars_home_alhamra with result: not_find
# Processed louts_furnished_apartments with result: not_find
# Processed gilden_new_umm_alqura_furnished_apartments with result: not_find
# Processed the_velvet_inn with result: not_find
# Processed qasr_almanar with result: not_find
# Processed sahab_chalet with result: not_find
# Processed asturat_hira_furnished_apartments with result: not_find
# Processed riyadh_ronza_nanis_hotel with result: not_find
# Processed ronza_land_2 with result: not_find
# Processed maden_taibah_hotel with result: not_find
# Processed gh_hotel_2 with result: not_find
# Processed marin_suites_albadiaa with result: not_find
# Processed seven_garden_airport with result: not_find
# Processed dar_ward with result: not_find
# Processed zahrat_al_lavender_hotel with result: not_find
# Processed msaken_al_hjaz_al_zahabia with result: not_find
# Processed manar_altawhid_2 with result: not_find
# Processed alrahaba_almakkah_hotel_3 with result: not_find
# Processed alansar_apartment with result: not_find
# Processed lojain_west with result: not_find
# Processed laly_el_fakhma_appartment with result: not_find
# Processed luluat_alshaati with result: not_find
# Processed rosa_al_tahlia_hotel_suites with result: not_find
# Processed noor_alraqia with result: not_find
# Processed alzaytooni with result: not_find
# Processed star_tallin_al_khalig_furnished_apartments with result: not_find
# Processed rawafd_sheikha with result: not_find
# Processed rahet_aldeef_furnished_apartments with result: not_find
# Processed qemt_aknan_hotel_apartments with result: not_find
# Processed qasr_aljoud with result: not_find
# Processed rihanna_rose_furnished_apartments with result: not_find
# Processed almasem_5_hotel_suites with result: not_find
# Processed rokn_venice_furnished_apartments with result: not_find
# Processed belqis_houses_furnished_apartments with result: not_find
# Processed open_hotel_6 with result: not_find
# Processed alyamama_olyaa_palace with result: not_find
# Processed laylat_mabeet_hotel_suites with result: not_find
# Processed taleen_al_riyadh_furnished_apartments with result: not_find
# Processed al_muhaidib_al_suwaidi_furnished_apartments with result: not_find
# Processed dyala_2_furnished_apartments with result: not_find
# Processed adwaa_alsalam_hotel with result: find
# Processed bedour_al_sharq_2 with result: find
# Processed hayat_al_rose_for_furnished_apartment with result: find
# Processed vivienda_hotel_villas_jeddah with result: find
# Processed orient_jewel_for_the_serviced_apartments_jwhr_lshrq_llshqq_lmkhdwm with result: find
# Processed emmar_al_dyar with result: find
# Processed mabaat_al_nuzhah_561 with result: find
# Processed golden_andalus_abha with result: not_find
# Processed fadet_talla_served_apartmet_1 with result: not_find
# Processed emaar_austorah with result: not_find
# Processed arto_residential_units with result: not_find
# Processed jawaher_al_malqa_apartments with result: not_find
# Processed time_luxury_furnished_apartments with result: not_find
# Processed mezab_al_baha with result: not_find
# Processed bnbme_riviera8_2_bdr_apartments with result: not_find
# Processed bnbme_riviera22_2_bdr_apartments with result: not_find
# Processed glamour_tabba_apartments with result: not_find
# Processed vip_resort_chalet_20 with result: not_find
# Processed vip_resort_chalet_21 with result: not_find
# Processed sama_al_amany_hotel with result: not_find
# Processed pearl_coral_furnished_apartment with result: not_find
# Processed shelter_house_furniesh_apartment with result: not_find
# Processed telal_ashbelia_furnished_apartments with result: not_find
# Processed kyan_shada_2 with result: not_find
# Processed grand_plaza_hotel_16 with result: not_find
# Processed lavanta_serviced_apartments with result: not_find
# Processed durat_safana_furnished_apartments with result: not_find
# Processed shejoun_furnished_apartments with result: not_find
# Processed jenan_furnished_apartments with result: not_find
# Processed asala_western_for_furnished_units with result: find
# Processed broad_residential_units with result: find
# Processed bellevue_park_royal_hotel with result: find
# Processed damac_aljawharah_30_floor_apartment_with_sea_view_jaccuzi_shq_fy_brj_dmk_ldwr_30_grftyn_nwm_wsl_m_jkwzy_mtl_l_lbhr_mbshrh with result: find
# Processed aan_apartment with result: find
# Processed alzuwain_hotel with result: find
# Processed alsharqia_seasons_suites with result: find
# Processed asdaa_alraha with result: find
# Processed kease_al_wahah_k2_royal_touch_ax68 with result: find
# Processed mabaat_hittin_552 with result: find
# Processed coov_2_hotel with result: find
# Processed private_room_near_jamarat with result: not_find
# Processed dort_al_almasa with result: not_find
# Processed wardt_al_dabab with result: not_find
# Processed mabaat_qurtubah_566 with result: not_find
# Processed riyadh_luxury_hotel_apartments with result: not_find
# Processed vip_resort_chalet_23 with result: not_find
# Processed rosefield_hotel with result: not_find
# Processed alaziziya_palaces_serviced_apartments with result: not_find
# Processed danat_real_state with result: not_find
# Processed nujoomalsharqya2 with result: not_find
# Processed rawabi_al_khobar_suites with result: not_find
# Processed doolv_hotel_3 with result: not_find
# Processed sama_furnished_apartments_2 with result: not_find
# Processed qasser_dhyafah_alsharq with result: not_find
# Processed hala_al_khobar_hotel with result: not_find
# Processed mian_suites_furnished_apartments with result: not_find
# Processed roken_tasis_serviced_apartments with result: not_find
# Processed blue_flowers_furnished_apartments with result: not_find
# Processed anika_furnished_apartment with result: not_find
# Processed aknaf_sraya_furnished_apartments with result: not_find
# Processed luna_homes with result: not_find
# Processed suite_777 with result: not_find
# Processed mabaat_al_narjis_2br_525 with result: not_find
# Processed bnbme_alajlan_riviera33 with result: find
# Processed al_haram_hotel with result: not_find
# Processed msaa_aljoud_furnished_apartments with result: not_find
# Processed al_abanos with result: not_find
# Processed alhasnaa_almutatawirah_furnished_apartments with result: not_find
# Processed hala_altmayoz with result: not_find
# Processed ghzali_residential_units with result: not_find
# Processed cloud_dream with result: not_find
# Processed al_kiswah_tower_2_hotel with result: not_find
# Processed kease_ar_rabi_d82_royal_design_gz15 with result: not_find
# Processed kease_ar_rabi_d81_royal_design_ag53 with result: not_find
# Processed kurtuba_al_azizya_hotel_2 with result: not_find
# Processed kawtar_aldiafeh with result: not_find
# Processed cent_alazeziah_hotel with result: not_find
# Processed alrawd with result: not_find
# Processed raheeq_al_madina with result: not_find
# Processed durrat_jawana with result: not_find
# Processed dan_platinum with result: not_find
# Processed blue_rose_hotel_2 with result: not_find
# Processed aseel_apartments with result: not_find
# Processed raweat_al_narjis with result: not_find
# Processed aryaf_hotel with result: not_find
# Processed dana_el_mohamadya with result: not_find
# Processed nawaret_al_mnsek with result: not_find
# Processed al_zaytoun_suites with result: not_find
# Processed khaled_el_gwaily_furnished_apartments with result: not_find
# Processed qasr_alqobah_furnished_apartments with result: not_find
# Processed hilz_hotel with result: not_find
# Processed dar_ramah with result: not_find
# Processed al_joud_house_furnished_apartments with result: not_find
# Processed divan_resort with result: not_find
# Processed afal_furnished_apartment with result: not_find
# Processed sarah_furnished_apartments with result: find
# Processed viva_la_vida_hotel_3 with result: find
# Processed al_bateel_furnished_apartments with result: not_find
# Processed chalet_toot_salman with result: not_find
# Processed ketan_suites_furnished_apartments with result: not_find
# Processed noon_residence_hotel_suites with result: not_find
# Processed red_alanqood_salamah with result: not_find
# Processed alareen_park_abha with result: not_find
# Processed asis_rise with result: not_find
# Processed nayaf_hotel_suites with result: not_find
# Processed blgees_houses_furnished_apartments with result: not_find
# Processed yanbu_wings_furnished_apartments with result: not_find
# Processed durrat_almasakin_furnished_apartments with result: not_find
# Processed alyamama_ebeda with result: not_find
# Processed konoz_suites with result: not_find
# Processed amazing_homes_furnished_apartments with result: not_find
# Processed shazliah_nights_furnished_apartments with result: not_find
# Processed dalin_jeddeh with result: not_find
# Processed nayifat_furnished_apartments with result: not_find
# Processed jaoharat_al_manar_furnished_apartments with result: not_find
# Processed alnahdi_furnished_apartments_alawaby with result: not_find
# Processed golden_new_alsafa with result: not_find
# Processed qasr_jeddah with result: not_find
# Processed durrt_red_sea_furnished_apartments with result: not_find
# Processed orans_suites with result: not_find
# Processed selen_almetmiza_furnished_apartments with result: not_find
# Processed beach_life_2 with result: not_find
# Processed ajnha_almashreq with result: not_find
# Processed station_orjwan_lebanon with result: not_find
# Processed adles_furnished_apartments with result: not_find
# Processed ghzali_hotel with result: not_find
# Processed freesia_hotel_2 with result: not_find
# Processed kawther_life with result: not_find
# Processed ewg_alazizia_hotel with result: not_find
# Processed rahati_jazan_for_furnished_apartments with result: not_find
# Processed roza_oasis with result: not_find
# Processed ewg_alnuzha_hotel with result: not_find
# Processed dyar_elsadek with result: not_find
# Processed rest_blue_apart_hotel with result: not_find
# Processed elite_hotel_suites with result: not_find
# Processed fakhamatalmakan with result: not_find
# Processed almedina_house with result: not_find
# Processed shalihat_wasem with result: not_find
# Processed royalty_group with result: not_find
# Processed ahla_tayf_service_apartments with result: not_find
# Processed orient_nights_serviced_apartments_3 with result: not_find
# Processed ajnehat_kayan with result: not_find
# Processed badr_hostel_for_furnished_apartments with result: not_find
# Processed mawten_atheer with result: not_find
# Processed dar_hanin_furnished_apartments with result: not_find
# Processed seuof_al_shohada with result: find
# Processed golden_square_aparthotels_1_suqur_district with result: not_find
# Processed orans_international_2_hotel_appartments with result: not_find
# Processed qasr_elbasma with result: not_find
# Processed najmat_alisraa_alzahabia with result: not_find
# Processed joanne_second_gold_of_housing_units with result: not_find
# Processed dra_sanam_servied_appartements with result: not_find
# Processed kease_tawun_b513_royal_touch_ag81 with result: not_find
# Processed mustaqar_jasmine with result: not_find
# Processed burj_mayar with result: not_find
# Processed drwazh_alnkheel with result: not_find
# Processed somedays_hotel_suites with result: not_find
# Processed my_destination with result: not_find
# Processed dalla_house_furnished_apartment with result: not_find
# Processed rahti_hona_furnished_apartment with result: not_find
# Processed white_house_158 with result: not_find
# Processed sakb_furnished_apartemnt with result: not_find
# Processed jiwar_al_madina_hotel with result: not_find
# Processed masharef_almoden_suites with result: not_find
# Processed credi_hotel with result: find
# Processed ahleen_3 with result: find
# Processed palette_luxury_credi_hotel with result: not_find
# Processed azha_al_qsoor_3_furnished_apartments_2 with result: not_find
# Processed mabaat_al_aarid_532 with result: not_find
# Processed elite_suites_residential_unites with result: find
# Processed al_mamoun_hotel with result: find
# Processed dormira_furnished_apartments with result: find
# Processed lina_tower_furnished_apartments with result: find
# Processed mabaat_al_malqa_553 with result: find
# Processed mabaat_al_qirawan_557 with result: find
# Processed mabaat_alfayhaa_562 with result: find
# Processed kease_al_khalij_a9_royal_touch_ag92 with result: find
# Processed maather_al_eiman_ajyad_street with result: not_find
# Processed abraj_alreem with result: not_find
# Processed janadriya_suites_furnished_apartments with result: not_find
# Processed bnbme_riviera12_2_bdr_apartments with result: not_find
# Processed bnbme_riviera17_2_bdr_apartments with result: not_find
# Processed hyat_town with result: not_find
# Processed vip_resort_chalet_22 with result: not_find
# Processed mnazel_morjan with result: not_find
# Processed seven_continents_resorts with result: not_find
# Processed golden_elmidiaf_abha_hotel with result: not_find
# Processed kayan_apartment_hotel with result: not_find
# Processed madinah_deluxe_hotel with result: not_find
# Processed joman_furnished_apartment with result: not_find
# Processed reef_alsharqia with result: not_find
# Processed bodor_elsharq_2 with result: not_find
# Processed sidrat_nwal_serviced_apartment with result: not_find
# Processed bluesand_plaza with result: not_find
# Processed rawaad_altamaiyz with result: not_find
# Processed maset_almasem_hotel_apartments with result: not_find
# Processed nadra_furnished_apartment with result: not_find
# Processed kadi_furnished_apartments with result: not_find
# Processed wajehat_najran_furnished_apartments with result: not_find
# Processed saba_ohod_furnished_apartments with result: not_find
# Processed rabeea_rafal_3_furnished_apartments with result: not_find
# Processed rafyf_tower_furnished_apartment with result: not_find
# Processed rawabi_al_janoub_furnished_apartments with result: not_find
# Processed beach_pearl_3 with result: not_find
# Processed hodw_suites_for_furnished_apartment with result: not_find
# Processed sedra_mecca_hotel with result: find
# Processed diamond_elite_corner_furnished_apartments with result: not_find
# Processed rahat_taraf_furnished_apartments with result: not_find
# Processed elaf_suites_furnished_apartments with result: not_find
# Processed ayan_abha with result: not_find
# Processed fakhama_hotel with result: not_find
# Processed rimalal_jazirih_furnished_apartments with result: not_find
# Processed alreef_almumaiz_hotel with result: not_find
# Processed mnazlna_2_furnished_apartments with result: not_find
# Processed olaya_2_stella_stays with result: not_find
# Processed arjan_park_al_narjis_hotel with result: not_find
# Processed nuzol_alhijaz_6 with result: not_find
# Processed yesr_alsalam_furnished_apartments with result: not_find
# Processed red_waves_suites with result: not_find
# Processed leen_for_furnished_apartment with result: not_find
# Processed ajenha_safwa_taybah with result: not_find
# Processed triple_star_hotel with result: not_find
# Processed hams_bark_hotel with result: not_find
# Processed albakhera_plaza with result: not_find
# Processed kadi_suites with result: not_find
# Processed rabee_rafal2 with result: not_find
# Processed paradise_nice_hotel with result: not_find
# Processed albidaa_plaza with result: not_find
# Processed verdan_furnished_apartments with result: not_find
# Processed dyala_al_khalij with result: not_find
# Processed al_mayar_hotel with result: not_find
# Processed pansae_furnished_apartment with result: not_find
# Processed sahib_alarabya with result: not_find
# Processed razan_suites with result: not_find
# Processed fayiqa_plaza_furnished_apartments with result: not_find
# Processed baron_almasyf with result: not_find
# Processed square_venice_furnished_residential_units with result: not_find
# Processed albirg_furnished_apartment with result: not_find
# Processed sodfa_hotel with result: not_find
# Processed sowar_furnished_hotel_apartments with result: not_find
# Processed joud_altaif_furnished_apartments with result: not_find
# Processed hayat_town_2 with result: find
# Processed hikayet_abeer_hotel_apartment with result: find
# Processed karam_haraa_serviced_apartments with result: not_find
# Processed qimampark_5_abha with result: not_find
# Processed ramis_albokhary_furnished_apartments with result: not_find
# Processed arak_alsamra_for_furnished_apartment with result: not_find
# Processed alzumurud_residence_hotel_for_serviced_apartments with result: not_find
# Processed adwa_al_wady_furnished_apartments with result: not_find
# Processed daar_bilasan with result: not_find
# Processed diyar_wahet_nazeel with result: not_find
# Processed kease_ar_rabi_d2_royal_design_xz22 with result: not_find
# Processed residence_vip_chalets with result: find
# Processed nasiriat_aleulya with result: find
# Processed kease_malqa_379416_black_opal_gz19 with result: find
# Processed al_olayan_golden_hotel with result: not_find
# Processed diyar_alsaliheen_serviced_apartments with result: not_find
# Processed mabaat_hittin_saad_square_563 with result: not_find
# Processed lamst_al_saada with result: not_find
# Processed almasa_al_khalijia with result: not_find
# Processed al_shurfah_loft with result: not_find
# Processed mahd_al_resala_3_hotel with result: not_find
# Processed mahd_al_resala_1_hotel with result: not_find
# Processed bnbme_riviera27_1_bdr_apartments with result: not_find
# Processed bnbme_damac_esclusiva_1_bdr_apartments with result: not_find
# Processed al_ebraiz_palace_serviced_apartments with result: not_find
# Processed almuhaidb_almuhammadiah with result: not_find
# Processed mabaat_hittin_560 with result: find
# Processed oyo_661_al_tamayoz_al_raqi_al_faisaliyyah with result: not_find
# Processed safeer_almisk_hotel_mecca with result: not_find
# Processed makarem_al_hijra_hotel with result: not_find
# Processed xyz_hotel_al_tawon with result: not_find
# Processed bluesand_dorat_elnaifa with result: not_find
# Processed alkhobar_new_palace_hotel with result: not_find
# Processed al_massera_house_suite_hotel with result: not_find
# Processed alnaifah with result: not_find
# Processed fya_for_furnished_apartment with result: not_find
# Processed damask_hotel with result: not_find
# Processed aseel_al_sharq_serviced_apartments with result: not_find
# Processed al_aydi_furnished_apartment with result: not_find
# Processed alabra_palace_furnished_apartments with result: not_find
# Processed mnazel_alroya_furnished_apartments with result: not_find
# Processed golden_soudah with result: not_find
# Processed daret_alkhaleej_furnished_apartments with result: not_find
# Processed rose_alhamra_for_luxury_residential_units with result: not_find
# Processed velvet_1 with result: not_find
# Processed dar_alwedad_hotel with result: not_find
# Processed jeddah_vision with result: not_find
# Processed middle_east_2 with result: not_find
# Processed jeddah_luxury_stay with result: not_find
# Processed mahd_al_ressala_hotel_1 with result: not_find
# Processed cloud_hotel_resortsriyadh with result: not_find
# Processed al_muhaidb_al_mohammadiyyah_riyadh with result: not_find
# Processed nukhbat_faris_hotel_2 with result: not_find
# Processed meezab_anwar_mecca with result: not_find
# Processed awtad_almthdta_hotel_2 with result: not_find
# Processed waght_altamyoz_almadinah with result: not_find
# Processed elzaytooni_aldaaeri with result: not_find
# Processed alsant_tree_furnished_apartments with result: not_find
# Processed jeddah_shadows_furnished_apartments with result: not_find
# Processed al_dar_furnished_apartments with result: not_find
# Processed sun_set_furnished_apartments with result: not_find
# Processed danat_agadir_furnished_apartments with result: not_find
# Processed suhob_abha with result: not_find
# Processed al_jawhara_park_hotel with result: not_find
# Processed sama_najd with result: not_find
# Processed rwaad_mozhela with result: not_find
# Processed khaleej_palace_hotel with result: not_find
# Processed musk_rose_2 with result: not_find
# Processed trend_hotel_suites with result: not_find
# Processed alnakhla_serviced_apartments_2 with result: not_find
# Processed hona_yanbu_furnished_units with result: not_find
# Processed al_nakhla_resort with result: not_find
# Processed masaken_rafal_furnished_apartments with result: not_find
# Processed mariah_furnished_apartments with result: not_find
# Processed guana_serviced_apartments with result: not_find
# Processed rond_hotel_apartments with result: find
# Processed wajehat_al_tamayuz_serviced_apartments_2 with result: find
# Processed seven_homes_hotel with result: not_find
# Processed almuhaidb_jawazat with result: find
# Processed bhr_ryzydns_2_obhur_residence with result: find
# Processed khayal_hostel_serviced_apartments_2 with result: find
# Processed raweat_aseer_for_furnished_apartment with result: find
# Processed tras_furnished_aparatment with result: find
# Processed afaq_tourist with result: find
# Processed mirada_purple_obhur with result: not_find
# Processed nusk_al_eiman_almadinah_ex_ramada_almadinah with result: not_find
# Processed nafa_furnished_apartment with result: not_find
# Processed alkhobar_pearl with result: not_find
# Processed dorar_manzly_aparthotel with result: not_find
# Processed mazayya_furnished_apartment with result: not_find
# Processed qasr_alsahab with result: not_find
# Processed villas_lavender with result: not_find
# Processed golden_flower_2 with result: not_find
# Processed ritan_suites with result: not_find
# Processed jkhfurnished_apartment with result: not_find
# Processed rahti_2_furnished_apartments with result: not_find
# Processed clouds_and_stars_furnished_units_2 with result: not_find
# Processed taj_garnada_furnished_apartments with result: not_find
# Processed lamar_serviced_apartments with result: not_find
# Processed rose_furnished_apartments with result: not_find
# Processed althahbia_rahty_serviced_apartments with result: not_find
# Processed nawamis_for_serviced_apartments with result: not_find
# Processed visitor_furnished_apartments with result: not_find
# Processed tu_jardin_al_nahdah with result: not_find
# Processed lottaz_beach with result: not_find
# Processed abella_2 with result: not_find
# Processed beautat_al_samer with result: not_find
# Processed mera_park_hotel_suites with result: not_find
# Processed aber_khamis_mushayt_hotel_20km_from_abha with result: find
# Processed polaris_furnished_apartments with result: not_find
# Processed nilofer_leader_furnished_apartments with result: not_find
# Processed shama_jeddah with result: not_find
# Processed saryat_alhamra_furnished_apartments with result: not_find
# Processed al_asr_almasi_suite_apartments with result: not_find
# Processed msaken_al_jood with result: not_find
# Processed seyof_al_shuhada_hotel with result: not_find
# Processed hailla_inn with result: not_find
# Processed manar_altawheed_1 with result: not_find
# Processed goot_almasif_furnished_apartments with result: not_find
# Processed manazel_qebaa with result: not_find
# Processed nares_plus_alnuzha with result: not_find
# Processed taiba_suites_hotel with result: not_find
# Processed mezab_al_sabeq with result: not_find
# Processed alfakhriah_suites_hotel with result: not_find
# Processed liwan_alkhaleej with result: not_find
# Processed wharf_palace with result: not_find
# Processed daro_home with result: not_find
# Processed al_joon_furnished_apartments with result: not_find
# Processed blue_tower_hotel_apartments with result: not_find
# Processed beauty_rose_hotel_2 with result: not_find
# Processed dar_rafah_furnished_apartments with result: not_find
# Processed dar_hashem_fara_marouj with result: not_find
# Processed night_star_3 with result: not_find
# Processed golden_stone_hotel_3 with result: not_find
# Processed qaser_mobarak_furnished_apartments with result: not_find
# Processed hudua_almasa_furnished_apartments with result: not_find
# Processed zaman_homeland with result: find
# Processed manarat_al_madinah with result: find
# Processed manazel_maali_suites with result: find
# Processed kenan_jeddah with result: not_find
# Processed manazel_forsan with result: not_find
# Processed al_khozama_hotel_residences_kaust with result: not_find
# Processed mnazel_lina_serviced_apartments with result: not_find
# Processed mnazel_ewan_furnished_apartments with result: not_find
# Processed skoon_house_for_furnished_apartment with result: not_find
# Processed dar_almadina_furnished_apartments with result: not_find
# Processed diafat_alharmen_dar_alabrar with result: not_find
# Processed regency_jazan_furnished_apartment with result: not_find
# Updated file saved as 'not_find.xlsx'

# %% [markdown]
# ### Find total ids and not find total ids information

# %%
import pandas as pd

df = pd.read_excel('not_find.xlsx')

find_count = (df['ratehawk_present'] == 'find').sum()
not_find_count = (df['ratehawk_present'] == 'not_find').sum()

print(f"Number of find_count: {find_count}")
print(f"Number of not_find_count: {not_find_count}")
# Out:
# Number of find_count: 176
# Number of not_find_count: 935
